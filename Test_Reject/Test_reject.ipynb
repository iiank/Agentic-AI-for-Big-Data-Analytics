# %% [markdown]
# # BT4221 Project Group 4 — Test Reject: Test Area for Validate Cleaning

# %% [markdown]
# **Note:** To test if validate cleaning ever rejects the initial dataset state
#
# Conclusion: It rates the raw (completely uncleaned) dataset a 1.0 and quality "GOOD".
#
# However, it does correctly identify cleaning steps that need to be taken.

# %% [markdown]
# ## Environment Setup

# %%
import os
java_path = "C:\Program Files\Java\jdk-17.0.0.1"
os.environ['JAVA_HOME'] = java_path

# %% [markdown]
# ## Import Libraries

# %%
import json
import os
import numpy as np
from getpass import getpass
from typing import TypedDict, Optional, Literal, Any, Dict, List
from pydantic import BaseModel, Field
from openai import OpenAI

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql.functions import (
    col, year, month, dayofweek, hour, when,
    unix_timestamp, skewness, kurtosis,
    percentile_approx, count, isnan
)

from pyspark.ml.feature import StringIndexer, OneHotEncoder, Bucketizer, VectorAssembler, StandardScaler, MinMaxScaler
from pyspark.ml import Pipeline

from pyspark.storagelevel import StorageLevel

from langgraph.graph import StateGraph, END
from langgraph.types import interrupt, Command
from langgraph.checkpoint.memory import MemorySaver

from pathlib import Path
import psutil

from IPython.display import Image, display
from dotenv import load_dotenv

from ValidateCleaning_Skills import validate_cleaning, validate_test_split

# %% [markdown]
# ## Create Spark Session

# %% [markdown]
# ### Optimised Spark Session Config

# %%
cores = os.cpu_count()

total_ram_gb = psutil.virtual_memory().total / (1024 ** 3)
driver_memory_gb = int(total_ram_gb * 0.7)
driver_memory = f"{driver_memory_gb}g"

print(f"Cores: {cores}")
print(f"Driver Memory: {driver_memory}")

# Create SparkSession
if "spark" in locals():
    spark.stop()
    print("Existing Spark session stopped.")

os.environ["SPARK_LOCAL_IP"] = "127.0.0.1"
os.environ["SPARK_LOCAL_HOSTNAME"] = "localhost"

driver_memory = globals().get('driver_memory', "8g")
cores = globals().get('cores', "8")

spark = (
    SparkSession.builder
    .master("local[*]")
    .appName("BT4221_Group4")
    .config("spark.driver.host", "127.0.0.1")
    .config("spark.driver.bindAddress", "127.0.0.1")
    .config("spark.driver.port", "4050")
    .config("spark.blockManager.port", "4051")
    .config("spark.port.maxRetries", "50")
    .config("spark.driver.memory", driver_memory)
    .config("spark.sql.shuffle.partitions", cores * 3)
    .config("spark.default.parallelism", cores)
    .config("spark.sql.adaptive.enabled", "true")
    .config("spark.network.timeout", "300s")
    .config("spark.executor.heartbeatInterval", "30s")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("WARN")

# Verify SparkSession created successfully
print("App:", spark.sparkContext.appName)
print("Master:", spark.sparkContext.master)
print("Driver host:", spark.conf.get("spark.driver.host"))
# Out:
# Cores: 20
# Driver Memory: 44g
# App: BT4221_Group4
# Master: local[*]
# Driver host: 127.0.0.1

# %% [markdown]
# ### CSV to Parquet

# %%
# Convert original raw CSV to Parquet
# PROJECT_ROOT = Path.cwd().parent
# ORIGINAL_CSV_PATH = PROJECT_ROOT / "dataset" / "US_Accidents_March23.csv"

# if not ORIGINAL_CSV_PATH.exists():
#     raise FileNotFoundError(f"Original CSV not found at: {ORIGINAL_CSV_PATH}")

# print("Project root:", PROJECT_ROOT)
# print("Original CSV:", ORIGINAL_CSV_PATH)

# # Read csv
# df = spark.read.csv(str(ORIGINAL_CSV_PATH), header=True, inferSchema=True)

# # Set parquet path
# ORIGINAL_PARQUET_PATH = PROJECT_ROOT / "dataset" / "US_Accidents_March23_parquet"

# # Create directory if it doesn't exist
# ORIGINAL_PARQUET_PATH.mkdir(parents=True, exist_ok=True)

# # Write to parquet path
# df.write.mode("overwrite").parquet(str(ORIGINAL_PARQUET_PATH))

# print("Original Parquet:", ORIGINAL_PARQUET_PATH)
# Out:
# Project root: c:\Users\Kayle\OneDrive\Desktop\BT\BT4221\finalproj
# Original CSV: c:\Users\Kayle\OneDrive\Desktop\BT\BT4221\finalproj\dataset\US_Accidents_March23.csv
# Original Parquet: c:\Users\Kayle\OneDrive\Desktop\BT\BT4221\finalproj\dataset\US_Accidents_March23_parquet

# %% [markdown]
# ### Load Dataset

# %%
# Train test split original parquet
PROJECT_ROOT = Path.cwd().parent

ORIGINAL_PARQUET_PATH = PROJECT_ROOT / "dataset" / "US_Accidents_March23_parquet"
unclean_df = spark.read.parquet(str(ORIGINAL_PARQUET_PATH))

# %%
train_df, test_df = unclean_df.randomSplit([0.8, 0.2], seed=42)
RUNTIME_DF = train_df

# %% [markdown]
# ## Create Agent State (Validate Cleaning + Feature Engineering)

# %%
class AgentState(TypedDict):
    # --- Phase 1: Cleaning Validation ---
    profile_train: Optional[dict]           # train profile consumed by FE
    profile_test: Optional[dict]            # separate test profile/validation
    cleaning_plan: Optional[dict]           # optional future cleaning plan
    validation_status: Optional[str]        # approved | rejected | stopped
    validation_message: Optional[str]       # details for final decision
    auto_decision: Optional[dict]           # accept/reject payload from cleaning gate
    execution_log: list                     # step-by-step trace

    # --- Phase 2: Feature Engineering ---
    semantic_decisions: dict
    numeric_decisions: dict
    categorical_decisions: dict
    engineered_df_train_path: str           # Path to post-FE parquet
    engineered_df_test_path: str
    feature_cols: List[str]                 # Final assembler cols list
    feature_validation_report: dict         # Structural checks (Level 1)
    feature_stats_report: dict              # Statistical profile (Level 2)
    validation_iterations: int
    validation_passed: bool
    validation_failures: List[str]
    #ouptut from feature gate
    feature_auto_decision: Optional[dict]
    feature_validation_status: Optional[dict]
    feature_validation_message: Optional[str]
    cols_to_prune: Optional[List[str]]

# %% [markdown]
# ## Validate Cleaning Agent

# %%
def validate_cleaning_node(state: AgentState) -> AgentState:
    print("=" * 55)
    print(">> NODE 1: Running train profile + test validation...")
    print("=" * 55)

    # Train profile drives cleaning decisions and downstream FE recommendations.
    runtime_train_df = globals().get("train_df", RUNTIME_DF)
    train_profile = validate_cleaning(
        df=runtime_train_df,
        target_col="Severity",
        timestamp_cols=["Start_Time"]
    )

    # Test split is profiled separately for integrity checks only.
    runtime_test_df = globals().get("test_df")
    if runtime_test_df is not None:
        test_profile = validate_test_split(
            df_test=runtime_test_df,
            train_columns=runtime_train_df.columns,
            timestamp_cols=["Start_Time"]
        )
    else:
        test_profile = {
            "profile": {},
            "quality_score": "not_available",
            "schema_check": {
                "status": "skipped",
                "reason": "test_df is not loaded in current runtime"
            },
        }

    state["profile_train"] = train_profile
    state["profile_test"] = test_profile

    state.setdefault("execution_log", []).append(
        {
            "node": "profile",
            "quality_score": train_profile.get("quality_score"),
            "critical_issues": len(train_profile.get("profile", {}).get("quality_summary", {}).get("critical_issues", [])),
            "total_issues": train_profile.get("profile", {}).get("quality_summary", {}).get("total_issues", 0),
            "test_schema_status": test_profile.get("schema_check", {}).get("status", "unknown"),
        }
    )

    print("\n   Train profile stored in AgentState['profile_train']")
    print("   Separate test profile stored in AgentState['profile_test']")
    print("   Ready for accept/reject cleaning gate.")
    return state

# Direct post-profiling gate: decide whether cleaning is acceptable.
def cleaning_accept_reject_node(state: AgentState) -> AgentState:
    train_profile_bundle = state.get("profile_train") or {}
    nested_profile = train_profile_bundle.get("profile") or {}
    quality_summary = nested_profile.get("quality_summary") or {}

    raw_quality_score = train_profile_bundle.get("quality_score")
    quality_band = str(raw_quality_score or "").strip().lower()

    # Support both quality_score formats:
    # 1) numeric score (0-1)
    # 2) categorical band (good/moderate/poor)
    quality_value = None
    if isinstance(raw_quality_score, (int, float)):
        quality_value = max(0.0, min(1.0, float(raw_quality_score)))
    else:
        quality_value = {
            "good": 1.0,
            "moderate": 0.7,
            "poor": 0.2,
        }.get(quality_band, 0.0)

    total_issues = int(quality_summary.get("total_issues", 0) or 0)

    critical_issues = quality_summary.get("critical_issues", [])
    if not isinstance(critical_issues, list):
        critical_issues = []
    critical_issue_count = len(critical_issues)

    # Accept when critical issues are absent and quality passes baseline.
    accepted = (critical_issue_count == 0) and (quality_value >= 0.70)

    decision = "accept" if accepted else "reject"
    if accepted:
        validation_status = "approved"
        reason = (
            f"Accepted for feature engineering. quality_score={raw_quality_score}, "
            f"critical_issues={critical_issue_count}, total_issues={total_issues}."
        )
    else:
        validation_status = "rejected"
        reason = (
            f"Rejected after profiling. quality_score={raw_quality_score}, "
            f"critical_issues={critical_issue_count}, total_issues={total_issues}."
        )

    auto_decision = {
        "decision": decision,
        "quality_score": raw_quality_score,
        "quality_value": round(quality_value, 4),
        "critical_issue_count": critical_issue_count,
        "total_issues": total_issues,
        "reason": reason,
    }

    state["auto_decision"] = auto_decision
    state["validation_status"] = validation_status
    state["validation_message"] = reason
    state.setdefault("execution_log", []).append({"node": "cleaning_gate", **auto_decision})

    print("=" * 55)
    print(">> NODE 2: Cleaning accept/reject gate")
    print("=" * 55)
    print(json.dumps(auto_decision, indent=2))
    return state

def route_decision(state: AgentState) -> str:
    auto_decision = state.get("auto_decision") or {}
    if auto_decision.get("decision") == "accept":
        return "semantic_agent"
    return "end"

def create_secure_openai_client():
    """
    Create OpenAI client with secure API key handling.

    This function:
    1. Looks for OPENAI_API_KEY in environment variables
    2. Tests the connection with a simple API call
    3. Returns the client or None if setup fails
    """
    try:
        load_dotenv()  # Load .env file if it exists
    except ImportError:
        pass  # python-dotenv not installed, that's okay

    api_key = os.getenv('OPENAI_API_KEY')
    if not api_key:
        print("No OpenAI API key found.")
        print("Set environment variable: OPENAI_API_KEY=your_key")
        print("Or create .env file with: OPENAI_API_KEY=your_key")
        return None

    try:
        client = OpenAI(api_key=api_key)
        # Test connection with a simple API call
        models = client.models.list()
        print("OpenAI client created and tested successfully")
        return client
    except Exception as e:
        print(f"OpenAI client creation failed: {e}")
        print("Check your API key and internet connection")
        return None

# %% [markdown]
# ## Feature Engineering Agent

# %%
class TimeFeatureDecision(BaseModel):
    features_to_extract: List[Literal['is_rush_hour', ]]
    rationale: str

class ColumnEncodingDecision(BaseModel):
    column: str
    action: Literal['string_index_ohe', 'string_index_only', 'passthrough', 'drop']
    rationale: str

class BinSpec(BaseModel):
    column: str
    strategy: Literal["equal_width", "custom_cuts"]
    n_bins: Optional[int]=None
    cuts: Optional[List[float]] =None
    rationale: str

class InteractionSpecs(BaseModel):
    col_a: str
    col_b: str
    op: Literal["multiply","add", "ratio"]
    rationale: str

class ScalingDecisions(BaseModel):
    column: str
    action: Literal['scale', 'skip']
    rationale: str

class SemanticExpansionDecision(BaseModel):
    source_column: Literal["Weather_Condition", "Street"]
    target_column: str
    regex_pattern: str
    rationale: str
    support_estimate_pct: Optional[float] = None

class DropDecision(BaseModel):
    column: str
    rationale: str

class FeatureEngDecision(BaseModel):
    time_features: TimeFeatureDecision
    semantic_expansions: List[SemanticExpansionDecision] = Field(default_factory=list)
    column_encodings: List[ColumnEncodingDecision]
    bins: Optional[List[BinSpec]] = None
    interactions: Optional[List[InteractionSpecs]] = None

    apply_scaling: bool
    scaling_strategy: Optional[Literal["standard", "minmax"]] = None
    scaling_decisions: Optional[List[ScalingDecisions]] = None
    scaling_rationale: Optional[str] = None

    drop_after_encoding: List[DropDecision]
    assembler_cols: List[str]
    overall_rationale: str

# schemas for subagent ouputs making use of the above defined schemas
# for semantic agent
class SemanticDecisionList(BaseModel):
    semantic_expansions: List[SemanticExpansionDecision] = Field(default_factory=list)
    overall_rationale: str

# for numeric agent
class NumericDecisionList(BaseModel):
    time_features: Optional[TimeFeatureDecision] = None
    bins: Optional[List[BinSpec]] = Field(default_factory=list)
    interactions: Optional[List[InteractionSpecs]] = Field(default_factory=list)
    apply_scaling: bool
    scaling_strategy: Optional[Literal["standard", "minmax"]] = None
    scaling_decisions: Optional[List[ScalingDecisions]] = Field(default_factory=list)
    scaling_rationale: Optional[str] = None
    overall_rationale: str

# for categorical agent
class CategoricalDecisionList(BaseModel):
    column_encodings: List[ColumnEncodingDecision]
    drop_after_encoding: List[DropDecision]
    overall_rationale: str


def create_secure_openai_client():
    """
    Create OpenAI client with secure API key handling.

    This function:
    1. Looks for OPENAI_API_KEY in environment variables
    2. Tests the connection with a simple API call
    3. Returns the client or None if setup fails
    """
    try:
        load_dotenv()  # Load .env file if it exists
    except ImportError:
        pass  # python-dotenv not installed, that's okay

    api_key = os.getenv('OPENAI_API_KEY')
    if not api_key:
        print("No OpenAI API key found.")
        print("Set environment variable: OPENAI_API_KEY=your_key")
        print("Or create .env file with: OPENAI_API_KEY=your_key")
        return None

    try:
        client = OpenAI(api_key=api_key)
        # Test connection with a simple API call
        models = client.models.list()
        print("OpenAI client created and tested successfully")
        return client
    except Exception as e:
        print(f"OpenAI client creation failed: {e}")
        print("Check your API key and internet connection")
        return None

# Initialize the client
client = create_secure_openai_client()

def load_skill(filename: str) -> str:
    """Read a skill.md file from disk (supports both SKILLS/ and skills/)."""
    path = os.path.join("SKILLS", filename)
    with open(path, "r") as f:
        return f.read()

    raise FileNotFoundError(f"Skill file not found in SKILLS/ or skills/: {filename}")

def semantic_agent_node(state: AgentState) -> AgentState:
    all_recs = state["profile_train"].get("feature_eng_rec", [])
    semantic_plan = [rec for rec in all_recs if rec.get('action') == "extract_binary_features"]
    context_str = json.dumps({"semantic_tasks": semantic_plan}, indent=2)
    skill_doc = load_skill("skill_semantic_boolean_expansion.md")

    #retrieve feedback from validate feature eng gate on semantic boolean expansions
    iteration = state.get("validation_iterations",0)
    feedback_prompt = ""
    if iteration > 0 and state.get("feature_auto_decision"):
        prev_decision = state["feature_auto_decision"]
        bad_flags = prev_decision.get("suspicious_semantic_flags", [])
        
        if bad_flags:
            feedback_prompt = "\n===Feedback from previous failed attempt===\n"
            feedback_prompt += "Your previous regex patterns resulted in features with a true_ratio that was too low (rare) or too high (overly general). Do not use these same mappings again:\n"
            for flag in bad_flags:
                feedback_prompt += f"- Target {flag['target_column']} | Reason: {flag['reason']}\n"
            feedback_prompt += "Action: Broaden the regex by combining terms, or choose different more semnatic categories.\n"
    system_prompt=f"""You are the semantic feature engineer for a PySpark Pipeline predicting US accident severity.
    Your only job is to look at compound text columns and extract boolean flags using regex.

    ===SKILL MANUAL===
    {skill_doc}

    CRITICAL RULES:
    - EXHAUSTIVE COVERAGE: you MUST generate at least 10 distinct flags for Weather_Condition (eg. is_rain, is_snow, is_fog...)
    - You must generate at least 10 distinct flags for Street (eg. is_highway, is_local_street, is_country_road)
    - Write regex strictly in lowercase
"""
    user_prompt=f"Data profile:\n{context_str}\n"
    if feedback_prompt:
        user_prompt += feedback_prompt
    user_prompt += "\n Generate semantic expansions using the discovered keywords."
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}],
        response_format=SemanticDecisionList
    )

    #ouput logs for tracking agent behaviour
    decision = response.choices[0].message.parsed
    print("\n" + "="*60)
    print("SEMANTIC AGENT DECISIONS")
    print("="*60)
    for exp in decision.semantic_expansions:
        print(f"\n{exp.source_column:<18} -> {exp.target_column:<20} (Regex: {exp.regex_pattern})")
        print(f"Rationale: {exp.rationale}")
    print(f"\nOverall Rationale: {decision.overall_rationale}")
    print("="*60 + "\n")


    return {"semantic_decisions": json.loads(decision.model_dump_json())}

def numeric_agent_node(state: AgentState) -> AgentState:
    data_profile = state["profile_train"]["profile"]
    sliced_context = {
        "numerical_columns": data_profile.get("numerical_analysis",{}),
        "timestamp_columns": list(data_profile.get("timestamp_analysis", {}).keys()),
        "total_rows": data_profile.get("structural_overview").get("total_rows")
    }
    context_str = json.dumps(sliced_context, indent=2)
    skills = "\n---\n".join([
        load_skill("skill_extract_time_features.md"),
        load_skill("skill_bin_numeric.md"),
        load_skill("skill_compute_interaction_features.md"),
        load_skill("skill_scale_numeric.md")
    ])
    
    system_prompt = f"""You are the Numeric Feature Engineer for a PySpark pipeline predicting US accident severity.
Your job is to handle timestamps, numeric binning, numeric interactions, and continuous scaling.

=== SKILL MANUALS ===
{skills}

CRITICAL RULES:
- BINNING: You MUST apply 'skill_bin_numeric' to discretize at least 'Temperature(F)' and 'Visibility(mi)'. Use 'custom_cuts'.
- INTERACTIONS: You MUST invent at least 5 novel, logical interaction feature using multiply, add, subtract or ratio. 
    Domain knowldege: Think like a traffic safety engineer. Look for combinations that amplify driving danger:
    - Severe weather: compounding effects (eg. Wind_Speed * Precipitation implies a rain storm)
    - Freezing risks: interactions between Temperature and precipitation or humidity
    - Kinematics: Rates of travels, such as distance / duration (a proxy for speed or traffic flow)

"""
    user_prompt = f"Data Profile:\n{context_str}\n\nGenerate the numeric transformations."
    
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}],
        response_format=NumericDecisionList,
    )

    #ouput logs for tracking agent behaviour
    decision = response.choices[0].message.parsed
    print("\n" + "="*60)
    print("NUMERIC AGENT DECISIONS")
    print("="*60)
    if decision.time_features:
        print(f"\nTime Features: {decision.time_features.features_to_extract}")
        print(f"Rationale: {decision.time_features.rationale}")
    if decision.bins:
        for b in decision.bins:
            print(f"\nBinning: {b.column} ({b.strategy})")
            print(f"Rationale: {b.rationale}")
    if decision.interactions:
        for ix in decision.interactions:
            print(f"\nInteraction: {ix.col_a} {ix.op} {ix.col_b}")
            print(f"Rationale: {ix.rationale}")

    print(f"\nScaling Applied: {decision.apply_scaling} (Strategy: {decision.scaling_strategy})")
    if decision.scaling_decisions:
        for s in decision.scaling_decisions:
            print(f"- {s.column}: {s.action} | {s.rationale}")
    if decision.scaling_rationale:
        print(f"\nRationale: {decision.scaling_rationale}")
        
    print(f"\nOverall Rationale: {decision.overall_rationale}")
    print("="*60 + "\n")

    return {"numeric_decisions": json.loads(decision.model_dump_json())}
    
def categorical_agent_node(state: AgentState) -> AgentState:
    all_recs = state["profile_train"].get("feature_eng_rec", [])
    profile_data = state["profile_train"]["profile"]
    encoding_plan = [rec for rec in all_recs if rec.get("action") == "encode"]
    timestamps = list(profile_data.get("timestamp_analysis", {}).keys())
    sliced_context = {
        "encoding_tasks": encoding_plan,
        "timestamps_to_drop": timestamps
    }
    context_str = json.dumps(sliced_context, indent=2)
    skills = "\n---\n".join([
        load_skill("skill_encode_categorical.md"),
        load_skill("skill_drop_columns.md")
    ])
    
    system_prompt = f"""You are the Categorical Feature Engineer for a PySpark pipeline predicting US accident severity.
Your job is to encode the remaining string columns and designate which original columns to drop.

=== SKILL MANUALS ===
{skills}

CRITICAL RULES:
- For high cardinality columns (>20 unique values) like City, State, or Zipcode, you MUST use 'string_index_only' to prevent OOM errors.
- Always include 'Start_Time' and original encoded string columns in 'drop_after_encoding'.
- For every column in 'drop_after_encoding', you must provide a clear 'rationale' for dropping the column (eg. 'Dropped because it was one hot encoded', 'Dropped because temporal features were extracted')
"""
    user_prompt = f"Data Profile:\n{context_str}\n\nGenerate the categorical encodings and drop list."
    
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}],
        response_format=CategoricalDecisionList,
    )
    
    decision = response.choices[0].message.parsed
    print("\n" + "="*60)
    print("CATEGORICAL AGENT DECISIONS")
    print("="*60)
    for enc in decision.column_encodings:
        print(f"Encode: {enc.column:<22} -> {enc.action}")
        print(f" | Rationale: {enc.rationale}")
        
    print(f"\nColumns to Drop:")
    for drop in decision.drop_after_encoding:
        print(f" - Drop: {drop.column: <22} | Rationale: {drop.rationale}")
        
    print(f"\nOverall Rationale: {decision.overall_rationale}")
    print("="*60 + "\n")

    return {"categorical_decisions": json.loads(decision.model_dump_json())}

def execute_feature_eng(state: AgentState):
    train_data = train_df
    test_data = test_df
    
    # sub-agent decisions
    sem = SemanticDecisionList.model_validate(state["semantic_decisions"])
    num = NumericDecisionList.model_validate(state["numeric_decisions"])
    cat = CategoricalDecisionList.model_validate(state["categorical_decisions"])
    
    assembler_cols = []
    
    # operations applied to both train and test sets
    def apply_stateless_features(df):
        local_assembler_cols = []
        
        # time features
        if num.time_features:
            for feat in num.time_features.features_to_extract:
                if feat == "is_rush_hour":
                    df = df.withColumn("is_rush_hour", F.when(F.hour("Start_Time").between(7,9) | F.hour("Start_Time").between(17,19), 1).otherwise(0))
                    if "is_rush_hour" not in local_assembler_cols: local_assembler_cols.append("is_rush_hour")

        # semantic boolean expansions
        for exp in sem.semantic_expansions:
            if exp.source_column in df.columns:
                lower_col = F.lower(F.col(exp.source_column))
                df = df.withColumn(exp.target_column, lower_col.rlike(exp.regex_pattern).cast("integer")).fillna(0, subset=[exp.target_column])
                if exp.target_column not in local_assembler_cols: local_assembler_cols.append(exp.target_column)

        # numeric interactions
        ops = {
            "multiply": lambda a, b: F.col(a) * F.col(b), 
            "add": lambda a, b: F.col(a) + F.col(b), 
            "subtract": lambda a, b: F.col(a) - F.col(b),
            "ratio": lambda a, b: F.col(a) / (F.col(b) + F.lit(1e-6))
        }
        if num.interactions:
            for ix in num.interactions:
                if ix.col_a in df.columns and ix.col_b in df.columns:
                    out_col = f"{ix.col_a}_{ix.op}_{ix.col_b}"
                    df = df.withColumn(out_col, ops[ix.op](ix.col_a, ix.col_b))
                    if out_col not in local_assembler_cols: local_assembler_cols.append(out_col)

        # manual boolean encoding
        for field in df.schema.fields:
            if isinstance(field.dataType, T.BooleanType) and field.name != "Severity":
                df = df.withColumn(field.name, F.col(field.name).cast("integer"))
                if field.name not in local_assembler_cols: local_assembler_cols.append(field.name)
                
        return df, local_assembler_cols

    # Execute stateless operations on both train and test
    train_data, stateless_cols = apply_stateless_features(train_data)
    test_data, _ = apply_stateless_features(test_data)
    
    assembler_cols.extend(stateless_cols)

    # operations applied to train data only
    stages = []

    # numeric binning, find and apply splits based on training data only
    if num.bins:
        for b in num.bins:
            if b.column in train_data.columns:
                if b.strategy == "equal_width":
                    mn = train_data.agg({b.column: "min"}).collect()[0][0]
                    mx = train_data.agg({b.column: "max"}).collect()[0][0]
                    splits = [float(x) for x in np.linspace(mn, mx, b.n_bins + 1)]
                    splits[0], splits[-1] = float("-inf"), float("inf")
                else:
                    splits = [float("-inf")] + [float(c) for c in b.cuts] + [float("inf")]
                
                out_col = f"{b.column}_bin"
                bucketizer = Bucketizer(splits=splits, inputCol=b.column, outputCol=out_col, handleInvalid="keep")
                stages.append(bucketizer)
                assembler_cols.append(out_col)

    # categorical encoding
    for enc in cat.column_encodings:
        if enc.column in train_data.columns:
            if enc.action == "string_index_ohe":
                stages.append(StringIndexer(inputCol=enc.column, outputCol=f"{enc.column}_idx", handleInvalid="keep"))
                stages.append(OneHotEncoder(inputCol=f"{enc.column}_idx", outputCol=f"{enc.column}_ohe"))
                assembler_cols.append(f"{enc.column}_ohe")
            elif enc.action == "string_index_only":
                stages.append(StringIndexer(inputCol=enc.column, outputCol=f"{enc.column}_idx", handleInvalid="keep"))
                assembler_cols.append(f"{enc.column}_idx")
            elif enc.action == "passthrough":
                assembler_cols.append(enc.column)
                
    # gather remaining numeric columns for assembly
    for field in train_data.schema.fields:
        if isinstance(field.dataType, (T.DoubleType, T.IntegerType, T.FloatType, T.LongType)):
            if (field.name not in assembler_cols and 
                field.name != "Severity" and 
                not field.name.endswith("_idx")):
                assembler_cols.append(field.name)

    final_feature_cols = list(dict.fromkeys([c for c in assembler_cols if c != "Severity"])) 

    # fit on train data
    pipeline = Pipeline(stages=stages)
    fitted_model = pipeline.fit(train_data)
    
    # transform on train and test data
    train_engineered = fitted_model.transform(train_data)
    test_engineered = fitted_model.transform(test_data)

    for enc in cat.column_encodings:
        if enc.action == "string_index_only":
            raw_col = f"{enc.column}_idx_raw"
            final_col = f"{enc.column}_idx"
            if raw_col in train_engineered.columns:
                train_engineered = train_engineered.withColumn(final_col, F.col(raw_col).cast("double")).drop(raw_col)
                test_engineered = test_engineered.withColumn(final_col, F.col(raw_col).cast("double")).drop(raw_col)
                
    #drop base columns
    cols_to_drop = set([d.column for d in cat.drop_after_encoding])
    for enc in cat.column_encodings:
        if enc.action in ["string_index_ohe", "string_index_only"]:
            cols_to_drop.add(enc.column)
        if enc.action == "string_index_ohe":
            cols_to_drop.add(f"{enc.column}_idx")
        if enc.action == "string_index_only":
            cols_to_drop.add(f"{enc.column}_idx_raw")
        if enc.action =="drop":
            cols_to_drop.add(enc.column)

    if num.bins:
        for b in num.bins:
            cols_to_drop.add(b.column)
            
    for exp in sem.semantic_expansions:
        cols_to_drop.add(exp.source_column)
        
    existing_drop_cols = [c for c in cols_to_drop if c in train_engineered.columns]
    if existing_drop_cols:
        train_engineered = train_engineered.drop(*existing_drop_cols)
        test_engineered = test_engineered.drop(*existing_drop_cols)
    
    # Regenerate final feature cols after dropping
    final_feature_cols = [col for col in final_feature_cols if col in train_engineered.columns]

    os.makedirs(str(PROJECT_ROOT / "models"), exist_ok=True)
    train_out_path = str(PROJECT_ROOT / "dataset" / "engineered_df_train.parquet")
    test_out_path = str(PROJECT_ROOT / "dataset" / "engineered_df_test.parquet")
    
    #save pipeline model for use in modelling stage
    model_out_path = str(PROJECT_ROOT / "models" / "fe_pipeline_model")

    train_engineered.write.mode("overwrite").parquet(train_out_path)
    test_engineered.write.mode("overwrite").parquet(test_out_path)
    fitted_model.write().overwrite().save(model_out_path)
    
    print(f"Feature engineering compiled and executed. Assembled {len(final_feature_cols)} features.")

    return {
        "feature_cols": final_feature_cols,
        "engineered_df_train_path": train_out_path,
        "engineered_df_test_path": test_out_path,
        "fe_pipeline_model_path": model_out_path
    }

def validate_feature_eng(state: AgentState, df) -> dict:
    validation_failures = state.get("validation_failures", [])
    if validation_failures is None:
        validation_failures = []

    results = {"passed": True, "checks": []}

    def check(name, condition, detail):
        status = "PASS" if condition else "FAIL"
        results["checks"].append({"check": name, "status": status, "detail": detail})
        if not condition:
            results["passed"] = False

    feature_cols = state.get("feature_cols", [])
    
    check(
        "no_target_leakage",
        "Severity" not in feature_cols,
        "Severity excluded from assembler_cols" if "Severity" not in feature_cols else "Severity present in assembler_cols"
    )

    #check for nulls
    for col in feature_cols:
        if col in df.columns:
            n_null = df.filter(F.col(col).isNull()).count()
            check(f"no_nulls_{col}", n_null == 0, f"{n_null} nulls found" if n_null > 0 else "Clean")
            
    # cehck time features are in expected range
    num_decisions = state.get("numeric_decisions", {})
    time_feats = num_decisions.get("time_features", {})
    if time_feats and "features_to_extract" in time_feats:
        for feat in time_feats["features_to_extract"]:
            if feat == "is_rush_hour" and feat in df.columns:
                out_of_range = df.filter((F.col(feat) < 0) | (F.col(feat) > 1)).count()
                check(f"range_{feat}", out_of_range == 0, f"{out_of_range} rows out of [0, 1]" if out_of_range else "All in [0, 1]")
    
    # check dropped columns are actually gone
    cat_decisions = state.get("categorical_decisions", {})
    drop_decisions = cat_decisions.get("drop_after_encoding", {})
    expected_drops = set([d["column"] for d in drop_decisions])

    #get expected cols to be dropped from semantic and categorical agent
    sem_decisions = state.get("semantic_decisions", {})
    for exp in sem_decisions.get("semantic_expansions", {}):
        expected_drops.add(exp['source_column'])
    
    num_decisions = state.get("numeric_decisions", {})
    #only checking for bin decision, interaction base cols do not need to be dropped. Timestamp cols handled by categorical agent
    for bin_dec in num_decisions.get("numeric_decisions",{}):
        expected_drops.add(bin_dec["column"])

    surviving_columns = [col for col in expected_drops if col in df.columns]
    check(
        "dropped_columns_removed",
        len(surviving_columns) == 0,
        "All columns meant to be dropped are dropped" if len(surviving_columns) == 0 else f"Failed to drop: {','.join(surviving_columns)}"
    )
    
    print("\n=== Feature Engineering Validation Report ===")
    for c in results["checks"]:
        symbol = "✓" if c["status"] == "PASS" else "x"
        print(f"[{symbol}] {c['check']}: {c['detail']}")
    print(f"\nOverall: {'PASSED' if results['passed'] else 'FAILED'}")

    failures = [
        f"{c['check']}: {c['detail']}"
        for c in results["checks"]
        if c["status"] == "FAIL"
    ]

    return {
        "feature_validation_report": results,
        "validation_passed": results["passed"],
        "validation_failures": failures,
    }

def profile_engineered_features(df, state: AgentState) -> dict:
    total_rows = df.count()
    target_col = "Severity_Binary" if "Severity_Binary" in df.columns else "Severity"
    
    profile = {
        "structural_overview": {
            "total_rows": total_rows,
            "total_columns": len(df.columns),
            "column_types": {f.name: str(f.dataType) for f in df.schema.fields}
        },
        "target_analysis": {},
        "numerical_analysis": {},
        "boolean_and_binary_analysis": {},
        "categorical_indices_analysis": {},
        "vector_analysis": {}
    }
    
    # 1. inspect target cols and class imbalance 
    if target_col in df.columns:
        class_dist = df.groupBy(target_col).count().orderBy(target_col).collect()
        profile["target_analysis"]["class_balance"] = {
            str(r[target_col]): {
                "count": r["count"],
                "pct": round(r["count"] / total_rows * 100, 1)
            } for r in class_dist
        }
        
        if "0" in profile["target_analysis"]["class_balance"] and "1" in profile["target_analysis"]["class_balance"]:
            n_maj = profile["target_analysis"]["class_balance"]["0"]["count"]
            n_min = profile["target_analysis"]["class_balance"]["1"]["count"]
            profile["target_analysis"]["class_weight_ratio"] = round(n_maj / max(n_min, 1), 2)

    # 2. Categorize Columns for Single-Pass Processing
    dtypes = dict(df.dtypes)
    num_cols = []
    bool_cols = []
    vec_cols = []
    
    for c, t in dtypes.items():
        if c == target_col: continue
        
        if "vector" in t.lower():
            vec_cols.append(c)
        elif c.endswith("_idx"):
            cardinality = df.select(F.approx_count_distinct(c)).collect()[0][0]
            profile["categorical_indices_analysis"][c] = {"approx_cardinality": cardinality}
        elif t == "boolean":
            bool_cols.append(c)
        elif t in ["int", "double", "float", "bigint"]:
            num_cols.append(c)

    # 3. boolean cols
    if bool_cols:
        bool_exprs = [F.sum(F.when(F.col(c) == True, 1).otherwise(0)).alias(c) for c in bool_cols]
        bool_res = df.select(bool_exprs).first().asDict()
        
        for c in bool_cols:
            trues = bool_res[c]
            profile["boolean_and_binary_analysis"][c] = {
                "true_count": trues,
                "true_ratio": round(trues / max(total_rows, 1), 4),
                "type": "native_boolean"
            }

    # 4. numerics & semantic binary flags   
    if num_cols:
        stats_exprs = []
        for c in num_cols:
            stats_exprs.extend([
                F.mean(c).alias(f"{c}_mean"),
                F.stddev(c).alias(f"{c}_std"),
                F.min(c).alias(f"{c}_min"),
                F.max(c).alias(f"{c}_max"),
                F.skewness(c).alias(f"{c}_skew")
            ])
            
        num_res = df.select(stats_exprs).first().asDict()
        
        for c in num_cols:
            mn = num_res[f"{c}_min"]
            mx = num_res[f"{c}_max"]
            mean_val = num_res[f"{c}_mean"]
            
            # If the integer column only contains 0 and 1 (like our semantic regex outputs), 
            # it is mathematically a binary flag, not a continuous variable.
            if mn == 0 and mx == 1:
                profile["boolean_and_binary_analysis"][c] = {
                    "true_ratio": round(mean_val, 4) if mean_val is not None else 0.0,
                    "type": "binary_integer"
                }
            else:
                std_val = num_res[f"{c}_std"]
                skew_val = num_res[f"{c}_skew"]
                
                profile["numerical_analysis"][c] = {
                    "min": round(mn, 4) if mn is not None else None,
                    "max": round(mx, 4) if mx is not None else None,
                    "mean": round(mean_val, 4) if mean_val is not None else None,
                    "stddev": round(std_val, 4) if std_val is not None else None,
                    "skewness": round(skew_val, 4) if skew_val is not None else None,
                    "contains_negatives": (mn < 0) if mn is not None else False
                }

    
    # 5. vector analysis (OHE Outputs & Final Features Vector)
    if vec_cols:
        # Grab exactly 1 row to inspect vector sizes (Zero computation cost)
        first_row = df.select(vec_cols).head()
        if first_row:
            for c in vec_cols:
                vec = first_row[c]
                if vec is not None:
                    profile["vector_analysis"][c] = {
                        "vector_type": "SparseVector" if hasattr(vec, 'indices') else "DenseVector",
                        "vector_size": len(vec)
                    }

    return {"feature_stats_report": profile}

MAX_VALIDATION_RETRIES = 2

def validate_feature_eng_node(state: AgentState):
    df = spark.read.parquet(state["engineered_df_train_path"])

    val_report = validate_feature_eng(state, df)
    updated_state = {**state, **val_report}

    if updated_state["validation_passed"]:
        stats_report = profile_engineered_features(df, updated_state)
        updated_state.update(stats_report)
    else:
        updated_state["validation_iterations"] = state.get("validation_iterations", 0) + 1

    return updated_state
    fe_decision = (state.get("feature_auto_decision") or {}).get("decision")
    if fe_decision == "reject":
        if state.get("validation_iterations", 0) <= MAX_VALIDATION_RETRIES:
            return "retry"
    return "end"

def feature_eng_accept_reject_node(state: AgentState) -> AgentState:
    validation_passed = bool(state.get("validation_passed", False))
    feature_cols = state.get("feature_cols", []) or []
    feature_stats = state.get("feature_stats_report", {}) or {}
    sem_decisions = (state.get("semantic_decisions", {}) or {}).get("semantic_expansions", []) or []

    quality_issues = []
    warnings = []

    if not validation_passed:
        quality_issues.append("Feature validation checks failed")

    if not feature_cols:
        quality_issues.append("No engineered feature columns were produced")

    bool_profile = feature_stats.get("boolean_and_binary_analysis", {}) if isinstance(feature_stats, dict) else {}
    suspicious_semantic_flags = []

    for exp in sem_decisions:
        target_col = exp.get("target_column")
        regex = str(exp.get("regex_pattern", "")).strip()

        if not target_col:
            quality_issues.append("Semantic expansion has missing target_column")
            continue

        if target_col not in bool_profile:
            suspicious_semantic_flags.append({
                "target_column": target_col,
                "reason": "engineered semantic flag not found in final profile"
            })
            continue

        true_ratio = bool_profile[target_col].get("true_ratio")
        if isinstance(true_ratio, (int, float)):
            if true_ratio < 0.001:
                suspicious_semantic_flags.append({
                    "target_column": target_col,
                    "reason": f"true_ratio too low ({true_ratio:.4f}) -> likely over-specific regex"
                })
            elif true_ratio > 0.995:
                suspicious_semantic_flags.append({
                    "target_column": target_col,
                    "reason": f"true_ratio too high ({true_ratio:.4f}) -> likely over-broad regex"
                })

        if regex and len(regex) < 3:
            warnings.append(f"Semantic regex for {target_col} looks too short: '{regex}'")

    if sem_decisions and len(suspicious_semantic_flags) > max(3, int(len(sem_decisions) * 0.4)):
        quality_issues.append(
            "Too many semantic boolean mappings look suspicious; feature engineering likely needs revision"
        )

    accepted = len(quality_issues) == 0
    decision = "accept" if accepted else "reject"
    status = "approved" if accepted else "needs_more_feature_engineering"
    cols_to_prune = []
    
    #extract sus columns so that can be dropped in subsequent node, this is to avoid noise in the final dataset
    if accepted and suspicious_semantic_flags:
        cols_to_prune = [flag['target_column'] for flag in suspicious_semantic_flags]
        state["cols_to_prune"] = cols_to_prune

    if not accepted:
        state["validation_iterations"] = state.get("validation_iterations", 0) + 1

    summary_reason = (
        "Engineered features accepted for modeling."
        if accepted
        else "Engineered features rejected; additional feature engineering is recommended."
    )

    fe_auto_decision = {
        "decision": decision,
        "status": status,
        "validation_passed": validation_passed,
        "semantic_flags_reviewed": len(sem_decisions),
        "suspicious_semantic_flags": suspicious_semantic_flags,
        "warning_count": len(warnings),
        "quality_issues": quality_issues,
        "reason": summary_reason,
    }

    state["feature_auto_decision"] = fe_auto_decision
    state["feature_validation_status"] = status
    state["feature_validation_message"] = summary_reason
    state.setdefault("execution_log", []).append({"node": "feature_eng_gate", **fe_auto_decision})

    print("=" * 55)
    print(">> NODE: Feature engineering accept/reject gate")
    print("=" * 55)
    print(json.dumps(fe_auto_decision, indent=2))

    return state

def prune_features_node(state: AgentState) -> AgentState:
    """
    this takes in the suspicious columns identified in the feature gate and drops them
    updates feature_cols, feature_stats_report and feature_validation_report to avoid stale state
    """
    cols_to_prune = state.get("cols_to_prune") or []
    if not cols_to_prune:
        print("No columns to prune. Proceeding...")
        return state
    
    print(f"\n" + "="*60)
    print(f">> NODE: Auto-Pruning {len(cols_to_prune)} sparse features")
    print(f"="*60)
    print(f"Dropping physical columns: {cols_to_prune}")

    #update engineered dataframe and rewrite to parquet
    train_df = spark.read.parquet(state["engineered_df_train_path"])
    existing_cols_train = [c for c in cols_to_prune if c in train_df.columns]
    if existing_cols_train:
        train_df = train_df.drop(*existing_cols_train)
        new_train_path = str(PROJECT_ROOT / "dataset" / "engineered_df_train_pruned.parquet")
        train_df.write.mode("overwrite").parquet(new_train_path)
        state['engineered_df_train_path'] = new_train_path
        

    test_df = spark.read.parquet(state["engineered_df_test_path"])
    existing_cols_test = [c for c in cols_to_prune if c in test_df.columns]
    if existing_cols_test:
        test_df = test_df.drop(*existing_cols_test)
        new_test_path = str(PROJECT_ROOT / "dataset" / "engineered_df_test_pruned.parquet")
        test_df.write.mode("overwrite").parquet(new_test_path)
        state['engineered_df_test_path'] = new_test_path
        
    print("Feature engineered train and test parquest data succesfully pruned and saved")
    
    #update feature cols
    state['feature_cols'] = [c for c in state.get("feature_cols", []) if c not in cols_to_prune]

    #update feature stats report
    stats = state.get("feature_stats_report", {})
    if stats:
        #update boolean section
        bool_profile = stats.get("boolean_and_binary_analysis", {})
        for col in cols_to_prune:
            bool_profile.pop(col, None)

        #update overview section
        structure = stats.get("structural_overview", {})
        col_types = structure.get("column_types", {})
        for col in cols_to_prune:
            col_types.pop(col, None)
        
        if "total_columns" in structure:
            structure['total_columns'] = len(col_types)
    
    #update feature_validation_report
    val_report = state.get("feature_validation_report")
    if "checks" in val_report:
        val_report["checks"] = [
            check for check in val_report["checks"]
            if not any(pruned_col in check["check"] for pruned_col in cols_to_prune)
        ]
    print("AgentState succesfully updated after pruning suspicious columns")
    print("="*60 + "\n")
    return state

def route_after_validation(state: AgentState):
    if not state.get("validation_passed", False):
        if state.get("validation_iterations", 0) <= MAX_VALIDATION_RETRIES:
            return "retry"
        return "end"
    return "feature_eng_gate"

def route_after_feature_gate(state: AgentState):
    fe_decision = (state.get("feature_auto_decision") or {}).get("decision")
    if fe_decision == "reject":
        if state.get("validation_iterations", 0) <= MAX_VALIDATION_RETRIES:
            return "retry"
    return "end"
# Out:
# OpenAI client created and tested successfully

# %% [markdown]
# ## Pipeline Implementation in Langgraph

# %% [markdown]
# ### Langgraph Pipeline (profiling -> accept/reject -> feature engineering)

# %%
def build_master_pipeline():
    workflow = StateGraph(AgentState)

    # Validate cleaning + direct accept/reject gate
    workflow.add_node("profile", validate_cleaning_node)
    workflow.add_node("cleaning_gate", cleaning_accept_reject_node)

    # Feature engineering nodes
    workflow.add_node("semantic_agent", semantic_agent_node)
    workflow.add_node("numeric_agent", numeric_agent_node)
    workflow.add_node("categorical_agent", categorical_agent_node)
    workflow.add_node("compiler", execute_feature_eng)
    workflow.add_node("validate_fe", validate_feature_eng_node)
    workflow.add_node("feature_eng_gate", feature_eng_accept_reject_node)
    workflow.add_node("prune_features", prune_features_node)

    # Cleaning/profiling edges
    workflow.set_entry_point("profile")
    workflow.add_edge("profile", "cleaning_gate")
    workflow.add_conditional_edges(
        "cleaning_gate",
        route_decision,
        {
            "semantic_agent": "semantic_agent",
            "end": END,
        },
    )

    # Feature engineering edges
    workflow.add_edge("semantic_agent", "numeric_agent")
    workflow.add_edge("numeric_agent", "categorical_agent")
    workflow.add_edge("categorical_agent", "compiler")
    workflow.add_edge("compiler", "validate_fe")

    # Retry if FE validation fails, else run FE gate
    workflow.add_conditional_edges(
        "validate_fe",
        route_after_validation,
        {
            "retry": "semantic_agent",
            "feature_eng_gate": "feature_eng_gate",
            "end": END,
        },
    )

    # Retry if FE gate rejects, else end
    workflow.add_conditional_edges(
        "feature_eng_gate",
        route_after_feature_gate,
        {
            "retry": "semantic_agent",
            "end": "prune_features",
        },
    )
    workflow.add_edge("prune_features", END)
    return workflow.compile(checkpointer=MemorySaver())

# %% [markdown]
# ### Execute Pipeline

# %%
pipeline = build_master_pipeline()
config = {"configurable": {"thread_id": "us-accidents-run-001"}}
initial_state = {
    "train_df_path": str(PROJECT_ROOT / "dataset" / "train_parquet"),
    "test_df_path": str(PROJECT_ROOT / "dataset" / "test_parquet"),
    "engineered_df_train_path": str(PROJECT_ROOT / "dataset" / "engineered_df_train.parquet"),
    "engineered_df_test_path": str(PROJECT_ROOT / "dataset" / "engineered_df_test.parquet"),
    "profile_train": None,
    "profile_test": None,
    "auto_decision": None,
    "validation_status": None,
    "validation_message": None,
    "feature_auto_decision": None,
    "feature_validation_status": None,
    "feature_validation_message": None,
    "execution_log": [],
    "validation_iterations": 0,
}

final_state = pipeline.invoke(initial_state, config=config)
print("\n" + "=" * 55)
print("PIPELINE RESULT")
print("=" * 55)
print(f"validation_status: {final_state.get('validation_status')}")
print(f"validation_message: {final_state.get('validation_message')}")
print(f"auto_decision: {final_state.get('auto_decision')}")
print(f"feature_validation_status: {final_state.get('feature_validation_status')}")
print(f"feature_validation_message: {final_state.get('feature_validation_message')}")
print(f"feature_auto_decision: {final_state.get('feature_auto_decision')}")

print("\nExecution log:")
for i, row in enumerate(final_state.get("execution_log", []), 1):
    print(f"\n  Step {i}: {row}")

if final_state.get("feature_validation_status") == "approved":
    print("\nPIPELINE COMPLETE!")
    print(f"Successfully engineered {len(final_state['feature_cols'])} features.")
    print(f"Train data saved to: {final_state['engineered_df_train_path']}")
    print(f"Test data saved to: {final_state['engineered_df_test_path']}")
    print("Features ready for modeling:", final_state['feature_cols'])
else:
    if final_state.get("validation_status") == "rejected":
        print("\nPIPELINE STOPPED: cleaning rejected after profiling.")
    else:
        print("\nPIPELINE ENDED: feature engineering requires further refinement.")
# Out:
# =======================================================
# >> NODE 1: Running train profile + test validation...
# =======================================================
# Profiling 6,183,468 rows x 46 columns...
# ✓ Section 1: Structural overview complete
# ✓ Section 2: Missing value analysis complete
# ✓ Section 3: Numerical column analysis complete
# ✓ Section 4: Categorical column analysis complete
# ✓ Section 5: Timestamp analysis complete
# ✓ Section 6: Target column analysis complete
# ✓ Section 7: Correlation analysis complete
# ✓ Section 8: Generate agent recommendations complete
# ✓ Profile complete. Quality Score: GOOD
#
#    Train profile stored in AgentState['profile_train']
#    Separate test profile stored in AgentState['profile_test']
#    Ready for accept/reject cleaning gate.
# =======================================================
# >> NODE 2: Cleaning accept/reject gate
# =======================================================
# {
#   "decision": "accept",
#   "quality_score": "good",
#   "quality_value": 1.0,
#   "critical_issue_count": 0,
#   "total_issues": 0,
#   "reason": "Accepted for feature engineering. quality_score=good, critical_issues=0, total_issues=0."
# }
#
# ============================================================
# SEMANTIC AGENT DECISIONS
# ============================================================
#
# Street             -> is_highway           (Regex: i-|hwy|highway|expressway|fwy)
# Rationale: Indicates if the street is a highway or similar type of road.
#
# Street             -> is_local_street      (Regex: rd|st|ave|blvd|drive|dr)
# Rationale: Identifies local streets, which are common in urban settings.
#
# Street             -> is_county_road       (Regex: county|cr-|state|sr-)
# Rationale: Captures county or state roads which are significant for navigation.
#
# Street             -> is_us_route          (Regex: us)
# Rationale: Specifically identifies US routes which are essential for cross-country travel.
#
# Street             -> is_business_route    (Regex: b-|business)
# Rationale: Targets business routes that provide access to commercial areas.
#
# Street             -> is_urban_road        (Regex: city|urban|town|local)
# Rationale: Covers urban roads that typically fall under smaller local jurisdictions.
#
# Street             -> is_state_route       (Regex: state|sr-)
# Rationale: Captures state routes that are vital for regional connectivity.
#
# Street             -> is_arterial_road     (Regex: arterial|major)
# Rationale: Identifies major roads that facilitate high volumes of traffic.
#
# Street             -> is_residential_street (Regex: residential|home|subdivision)
# Rationale: Indicates streets primarily used for residential access.
#
# Street             -> is_service_road      (Regex: service|access|feeder|frontage)
# Rationale: Marks service roads that provide access to main roads or properties.
#
# Weather_Condition  -> is_rain              (Regex: rain|storm|drizzle|shower|thunder)
# Rationale: Identifies various forms of rain, which are critical for accident severity prediction.
#
# Weather_Condition  -> is_snow              (Regex: snow|sleet|ice|pellets|squall)
# Rationale: Captures wintry conditions that significantly impact driving hazards.
#
# Weather_Condition  -> is_fog               (Regex: fog|haze|mist|visibility)
# Rationale: Indicates reduced visibility conditions which contribute to accidents.
#
# Weather_Condition  -> is_overcast          (Regex: overcast|cloudy|dark)
# Rationale: Identifies overcast conditions which may result in decreased visibility.
#
# Weather_Condition  -> is_clear             (Regex: clear)
# Rationale: Marks clear weather conditions which are ideal for driving.
#
# Weather_Condition  -> is_light_precipitation (Regex: light|drizzle)
# Rationale: Covers light precipitation scenarios that may affect driving subtly.
#
# Weather_Condition  -> is_heavy_precipitation (Regex: heavy|torrential|downpour)
# Rationale: Identifies heavy rainfall conditions which drastically affect road safety.
#
# Weather_Condition  -> is_thunderstorm      (Regex: thunder|lightning)
# Rationale: Captures thunderstorms, which are extreme conditions affecting driving.
#
# Weather_Condition  -> is_winter_storm      (Regex: blizzard|winter|icy)
# Rationale: Targets severe winter storm conditions that result in hazardous driving.
#
# Weather_Condition  -> is_variable_conditions (Regex: changing|variable)
# Rationale: Identifies conditions that may vary quickly, leading to unpredictable driving conditions.
#
# Overall Rationale: The above expansions are designed to capture broad categories relevant to accident severity prediction without creating rare or overly specific flags. Each regex is constructed to ensure at least 1% support across the dataset.
# ============================================================
#
#
# ============================================================
# NUMERIC AGENT DECISIONS
# ============================================================
#
# Time Features: ['is_rush_hour']
# Rationale: Rush hours significantly increase the risk of accidents due to higher traffic volumes.
#
# Binning: Visibility(mi) (custom_cuts)
# Rationale: Binning Visibility into categories aids in isolating the impacts of near-zero visibility conditions during accidents.
#
# Binning: Temperature(F) (custom_cuts)
# Rationale: Categorizing Temperature helps identify risks associated with freezing temperatures and extreme heat.
#
# Interaction: Wind_Speed(mph) multiply Precipitation(in)
# Rationale: Higher Wind Speed coupled with Precipitation significantly worsens driving conditions, increasing accident severity.
#
# Interaction: Temperature(F) multiply Humidity(%)
# Rationale: High levels of Temperature along with Humidity create discomfort and reduced response times for drivers, raising accident risks.
#
# Interaction: Distance(mi) ratio Duration_Minutes
# Rationale: The ratio of Distance to Duration indicates the speed of travel and potential recklessness, which can lead to more severe accidents.
#
# Interaction: Wind_Speed(mph) multiply Temperature(F)
# Rationale: High Wind Speed and extreme temperatures can distract drivers and impair visibility, leading to accidents.
#
# Interaction: Pressure(in) ratio Visibility(mi)
# Rationale: A low pressure may align with poor visibility conditions, amplifying hazards on the road.
#
# Scaling Applied: True (Strategy: standard)
# - Temperature(F): scale | Temperature is a continuous variable with a normal distribution that needs to be scaled for model stability.
# - Humidity(%): scale | Humidity is also continuous and can impact accident severity, thus should be scaled.
# - Pressure(in): scale | Pressure is a continuous variable that can affect the weather conditions, influencing accident severity.
# - Visibility(mi): scale | Visibility, as a continuous metric, also requires scaling for effective model training.
# - Wind_Speed(mph): scale | Wind speed impacts driving conditions, thus it must be scaled for accurate model evaluation.
#
# Rationale: Scaling all continuous numeric features ensures better convergence in Logistic Regression and compatibility across all model pipelines.
#
# Overall Rationale: The transformations applied will enhance predictive capability by leveraging time decomposition, numerical binning, interaction effects, and scaling, all tailored towards amplifying critical factors influencing accident severity.
# ============================================================
#
#
# ============================================================
# CATEGORICAL AGENT DECISIONS
# ============================================================
# Encode: Source                 -> string_index_ohe
#  | Rationale: Column has 3 unique values and can be one-hot encoded.
# Encode: Country                -> string_index_ohe
#  | Rationale: Column has 1 unique value and can be one-hot encoded.
# Encode: Timezone               -> string_index_ohe
#  | Rationale: Column has 5 unique values and can be one-hot encoded.
# Encode: Sunrise_Sunset         -> string_index_ohe
#  | Rationale: Column has 3 unique values and can be one-hot encoded.
# Encode: Civil_Twilight         -> string_index_ohe
#  | Rationale: Column has 3 unique values and can be one-hot encoded.
# Encode: Nautical_Twilight      -> string_index_ohe
#  | Rationale: Column has 3 unique values and can be one-hot encoded.
# Encode: Astronomical_Twilight  -> string_index_ohe
#  | Rationale: Column has 3 unique values and can be one-hot encoded.
# Encode: City                   -> string_index_only
#  | Rationale: Column has 13425 unique values and should be labeled encoded.
# Encode: County                 -> string_index_only
#  | Rationale: Column has 1855 unique values and should be labeled encoded.
# Encode: State                  -> string_index_only
#  | Rationale: Column has 49 unique values and should be labeled encoded.
# Encode: Zipcode                -> drop
#  | Rationale: Dropped due to high cardinality (728289 unique values).
# Encode: Airport_Code           -> string_index_only
#  | Rationale: Column has 2038 unique values and should be labeled encoded.
# Encode: Wind_Direction         -> string_index_only
#  | Rationale: Column has 25 unique values and should be labeled encoded.
#
# Columns to Drop:
#  - Drop: Start_Time             | Rationale: Raw timestamp must be removed.
#  - Drop: ID                     | Rationale: Original string column replaced by group_rare_categories_and_label_encode.
#  - Drop: Description            | Rationale: Original string column replaced by group_rare_categories_and_label_encode.
#
# Overall Rationale: Encoded nominal columns using suitable methods while dropping high cardinality and raw timestamp features.
# ============================================================
#
# Feature engineering compiled and executed. Assembled 62 features.
#
# === Feature Engineering Validation Report ===
# [✓] no_target_leakage: Severity excluded from assembler_cols
# [✓] no_nulls_is_rush_hour: Clean
# [✓] no_nulls_is_highway: Clean
# [✓] no_nulls_is_local_street: Clean
# [✓] no_nulls_is_county_road: Clean
# [✓] no_nulls_is_us_route: Clean
# [✓] no_nulls_is_business_route: Clean
# [✓] no_nulls_is_urban_road: Clean
# [✓] no_nulls_is_state_route: Clean
# [✓] no_nulls_is_arterial_road: Clean
# [✓] no_nulls_is_residential_street: Clean
# [✓] no_nulls_is_service_road: Clean
# [✓] no_nulls_is_rain: Clean
# [✓] no_nulls_is_snow: Clean
# [✓] no_nulls_is_fog: Clean
# [✓] no_nulls_is_overcast: Clean
# [✓] no_nulls_is_clear: Clean
# [✓] no_nulls_is_light_precipitation: Clean
# [✓] no_nulls_is_heavy_precipitation: Clean
# [✓] no_nulls_is_thunderstorm: Clean
# [✓] no_nulls_is_winter_storm: Clean
# [✓] no_nulls_is_variable_conditions: Clean
# [x] no_nulls_Wind_Speed(mph)_multiply_Precipitation(in): 1827007 nulls found
# [x] no_nulls_Temperature(F)_multiply_Humidity(%): 139419 nulls found
# [x] no_nulls_Wind_Speed(mph)_multiply_Temperature(F): 475229 nulls found
# [x] no_nulls_Pressure(in)_ratio_Visibility(mi): 149286 nulls found
# [✓] no_nulls_Amenity: Clean
# [✓] no_nulls_Bump: Clean
# [✓] no_nulls_Crossing: Clean
# [✓] no_nulls_Give_Way: Clean
# [✓] no_nulls_Junction: Clean
# [✓] no_nulls_No_Exit: Clean
# [✓] no_nulls_Railway: Clean
# [✓] no_nulls_Roundabout: Clean
# [✓] no_nulls_Station: Clean
# [✓] no_nulls_Stop: Clean
# [✓] no_nulls_Traffic_Calming: Clean
# [✓] no_nulls_Traffic_Signal: Clean
# [✓] no_nulls_Turning_Loop: Clean
# [x] no_nulls_Visibility(mi)_bin: 141807 nulls found
# [x] no_nulls_Temperature(F)_bin: 131243 nulls found
# [✓] no_nulls_Source_ohe: Clean
# [✓] no_nulls_Country_ohe: Clean
# [✓] no_nulls_Timezone_ohe: Clean
# [✓] no_nulls_Sunrise_Sunset_ohe: Clean
# [✓] no_nulls_Civil_Twilight_ohe: Clean
# [✓] no_nulls_Nautical_Twilight_ohe: Clean
# [✓] no_nulls_Astronomical_Twilight_ohe: Clean
# [✓] no_nulls_City_idx: Clean
# [✓] no_nulls_County_idx: Clean
# [✓] no_nulls_State_idx: Clean
# [✓] no_nulls_Airport_Code_idx: Clean
# [✓] no_nulls_Wind_Direction_idx: Clean
# [✓] no_nulls_Start_Lat: Clean
# [✓] no_nulls_Start_Lng: Clean
# [x] no_nulls_End_Lat: 2722488 nulls found
# [x] no_nulls_End_Lng: 2722488 nulls found
# [✓] no_nulls_Distance(mi): Clean
# [x] no_nulls_Wind_Chill(F): 1599694 nulls found
# [x] no_nulls_Humidity(%): 139419 nulls found
# [x] no_nulls_Pressure(in): 112712 nulls found
# [x] no_nulls_Wind_Speed(mph): 457201 nulls found
# [x] no_nulls_Precipitation(in): 1762962 nulls found
# [✓] range_is_rush_hour: All in [0, 1]
# [✓] dropped_columns_removed: All columns meant to be dropped are dropped
#
# Overall: FAILED
#
# ============================================================
# SEMANTIC AGENT DECISIONS
# ============================================================
#
# Weather_Condition  -> is_fair              (Regex: fair)
# Rationale: Indicates fair weather conditions which are commonly encountered in accident data.
#
# Weather_Condition  -> is_cloudy            (Regex: cloudy|overcast|scattered|clouds)
# Rationale: Capture various forms of cloudy weather conditions which impacts visibility and may lead to accidents.
#
# Weather_Condition  -> is_clear             (Regex: clear)
# Rationale: Identifies clear skies which are important for understanding the severity of accidents under good weather conditions.
#
# Weather_Condition  -> is_light_precip      (Regex: light|drizzle|shower)
# Rationale: Includes lighter forms of precipitation that can still influence driving conditions and accident occurrences.
#
# Weather_Condition  -> is_rain              (Regex: rain|storm|thunder|drizzle)
# Rationale: Captures various rain events which are significant contributors to accident severity.
#
# Weather_Condition  -> is_snow              (Regex: snow)
# Rationale: Essential for identifying winter weather conditions that increase accident severity.
#
# Weather_Condition  -> is_fog               (Regex: fog|mist|haze)
# Rationale: Critical for identifying low visibility conditions which can result in accidents.
#
# Weather_Condition  -> is_freezing_precip   (Regex: ice|sleet|pellets|squall)
# Rationale: Captures freezing conditions that create hazardous roads leading to accidents.
#
# Weather_Condition  -> is_winter_weather    (Regex: snow|sleet|ice)
# Rationale: Combines various winter related conditions impacting vehicle operation and safety.
#
# Weather_Condition  -> is_precipitation     (Regex: rain|snow|sleet|drizzle|shower)
# Rationale: General flag for any precipitation which affects driving conditions.
#
# Street             -> is_highway           (Regex: highway|hwy|i-|fwy|expressway)
# Rationale: Indicates highways and expressways which often have different accident severity dynamics.
#
# Street             -> is_local_street      (Regex: st|ave|blvd|rd|drive|dr)
# Rationale: Covers local streets and avenues where many accidents occur.
#
# Street             -> is_county_road       (Regex: county|cr-|sr-|state|route)
# Rationale: Flags county and state roads which can have distinct accident patterns.
#
# Street             -> is_us_highway        (Regex: us)
# Rationale: Specifically captures U.S. highways which may have different rules and traffic patterns.
#
# Street             -> is_urban_road        (Regex: city|town|urban)
# Rationale: Identifies roads that are within urban areas, likely experiencing higher accident rates.
#
# Street             -> is_non_highway       (Regex: ^((?!highway|hwy|i-|fwy).)*$)
# Rationale: Flags roads that are not highways, which could be significant for analysis purposes.
#
# Street             -> is_arterial_street   (Regex: arterial|major|throughway)
# Rationale: Identifies major roads that act as conduits for high traffic volumes and may have different accident trends.
#
# Street             -> is_residential_street (Regex: residential|subdivision|neighborhood)
# Rationale: Captures roads primarily in residential areas where accident dynamics differ significantly.
#
# Street             -> is_rural_road        (Regex: rural|farm|dirt|gravel)
# Rationale: Indicates rural and unpaved roads where specific safety issues may arise.
#
# Street             -> is_unknown_type      (Regex: unknown|not specified|n/a)
# Rationale: Covers cases where the street type is unknown, important to handle missing data appropriately.
#
# Overall Rationale: The generated flags aim to represent broad categories of weather conditions and street types that affect accident severity, ensuring no individual flag is too rare or specific, thus maintaining a robust feature set.
# ============================================================
#
#
# ============================================================
# NUMERIC AGENT DECISIONS
# ============================================================
#
# Time Features: ['is_rush_hour']
# Rationale: Decomposing Start_Time into the is_rush_hour feature allows us to incorporate time-specific patterns that could significantly affect accident severity.
#
# Binning: Visibility(mi) (custom_cuts)
# Rationale: Binning Visibility into categories (poor, moderate, clear) helps capture its impact on driving conditions and accident severity.
#
# Binning: Temperature(F) (custom_cuts)
# Rationale: Binning Temperature into ranges (freezing, cold, mild, hot) allows us to reflect how temperature extremes could affect driver behavior and accident risks.
#
# Interaction: Wind_Speed(mph) multiply Precipitation(in)
# Rationale: The interaction between Wind Speed and Precipitation captures the compounding effect of severe weather, indicating increased risk during storms.
#
# Interaction: Temperature(F) multiply Humidity(%)
# Rationale: High temperature combined with high humidity increases stress and discomfort for drivers, potentially influencing their reaction and decision-making on the road.
#
# Interaction: Distance(mi) ratio Duration_Minutes
# Rationale: The ratio of Distance to Duration reveals speed, which can provide insights into how quickly drivers were traveling before an accident, affecting severity.
#
# Interaction: Visibility(mi) multiply Wind_Speed(mph)
# Rationale: Combining low visibility with high wind speeds could indicate dangerous driving conditions, leading to higher accident severity.
#
# Interaction: Temperature(F) multiply Precipitation(in)
# Rationale: This interaction explores the impact of temperature during precipitation, especially in freezing conditions that heighten accident risks.
#
# Scaling Applied: True (Strategy: standard)
# - Temperature(F): scale | Scaling Temperature ensures that it is normalized for use in gradient-based models, improving model convergence and interpretability.
# - Humidity(%): scale | Humidity must be scaled to maintain consistency across features, which is vital for effective modeling.
# - Pressure(in): scale | Pressure should be scaled as it may influence various interactions and overall model performance.
# - Visibility(mi): scale | Visibility scaling is critical to ensure that varying conditions are appropriately represented in distance-based models.
# - Wind_Speed(mph): scale | Wind Speed should be scaled for better integration into models that depend on distance or gradient.
#
# Rationale: Scaling all continuous numeric columns ensures that features are on a common scale, facilitating the performance of our models, particularly logistic regression and gradient-based models.
#
# Overall Rationale: The transformations applied, including time decomposition, binning of critical features, interaction analyses for severe conditions, and scaling of all continuous variables, align with the goal of predicting accident severity effectively.
# ============================================================
#
#
# ============================================================
# CATEGORICAL AGENT DECISIONS
# ============================================================
# Encode: Source                 -> string_index_ohe
#  | Rationale: Column has 3 unique values, using OHE.
# Encode: Country                -> string_index_ohe
#  | Rationale: Column has 1 unique value, using OHE.
# Encode: Timezone               -> string_index_ohe
#  | Rationale: Column has 5 unique values, using OHE.
# Encode: Sunrise_Sunset         -> string_index_ohe
#  | Rationale: Column has 3 unique values, using OHE.
# Encode: Civil_Twilight         -> string_index_ohe
#  | Rationale: Column has 3 unique values, using OHE.
# Encode: Nautical_Twilight      -> string_index_ohe
#  | Rationale: Column has 3 unique values, using OHE.
# Encode: Astronomical_Twilight  -> string_index_ohe
#  | Rationale: Column has 3 unique values, using OHE.
# Encode: City                   -> string_index_only
#  | Rationale: Column has 13425 unique values, using index only.
# Encode: County                 -> string_index_only
#  | Rationale: Column has 1855 unique values, using index only.
# Encode: State                  -> string_index_only
#  | Rationale: Column has 49 unique values, using index only.
# Encode: Zipcode                -> drop
#  | Rationale: Column has high cardinality and could cause issues.
# Encode: Airport_Code           -> string_index_only
#  | Rationale: Column has 2038 unique values, using index only.
# Encode: Wind_Direction         -> string_index_only
#  | Rationale: Column has 25 unique values, using index only.
#
# Columns to Drop:
#  - Drop: Start_Time             | Rationale: Dropped because it is a raw timestamp.
#  - Drop: ID                     | Rationale: Dropped because it has been label encoded.
#  - Drop: Description            | Rationale: Dropped because it has been label encoded.
#
# Overall Rationale: Encoded categorical variables and dropped original columns for clarity and to avoid duplication.
# ============================================================
#
# Feature engineering compiled and executed. Assembled 62 features.
#
# === Feature Engineering Validation Report ===
# [✓] no_target_leakage: Severity excluded from assembler_cols
# [✓] no_nulls_is_rush_hour: Clean
# [✓] no_nulls_is_fair: Clean
# [✓] no_nulls_is_cloudy: Clean
# [✓] no_nulls_is_clear: Clean
# [✓] no_nulls_is_light_precip: Clean
# [✓] no_nulls_is_rain: Clean
# [✓] no_nulls_is_snow: Clean
# [✓] no_nulls_is_fog: Clean
# [✓] no_nulls_is_freezing_precip: Clean
# [✓] no_nulls_is_winter_weather: Clean
# [✓] no_nulls_is_precipitation: Clean
# [✓] no_nulls_is_highway: Clean
# [✓] no_nulls_is_local_street: Clean
# [✓] no_nulls_is_county_road: Clean
# [✓] no_nulls_is_us_highway: Clean
# [✓] no_nulls_is_urban_road: Clean
# [✓] no_nulls_is_non_highway: Clean
# [✓] no_nulls_is_arterial_street: Clean
# [✓] no_nulls_is_residential_street: Clean
# [✓] no_nulls_is_rural_road: Clean
# [✓] no_nulls_is_unknown_type: Clean
# [x] no_nulls_Wind_Speed(mph)_multiply_Precipitation(in): 1827007 nulls found
# [x] no_nulls_Temperature(F)_multiply_Humidity(%): 139419 nulls found
# [x] no_nulls_Visibility(mi)_multiply_Wind_Speed(mph): 477262 nulls found
# [x] no_nulls_Temperature(F)_multiply_Precipitation(in): 1784454 nulls found
# [✓] no_nulls_Amenity: Clean
# [✓] no_nulls_Bump: Clean
# [✓] no_nulls_Crossing: Clean
# [✓] no_nulls_Give_Way: Clean
# [✓] no_nulls_Junction: Clean
# [✓] no_nulls_No_Exit: Clean
# [✓] no_nulls_Railway: Clean
# [✓] no_nulls_Roundabout: Clean
# [✓] no_nulls_Station: Clean
# [✓] no_nulls_Stop: Clean
# [✓] no_nulls_Traffic_Calming: Clean
# [✓] no_nulls_Traffic_Signal: Clean
# [✓] no_nulls_Turning_Loop: Clean
# [x] no_nulls_Visibility(mi)_bin: 141807 nulls found
# [x] no_nulls_Temperature(F)_bin: 131243 nulls found
# [✓] no_nulls_Source_ohe: Clean
# [✓] no_nulls_Country_ohe: Clean
# [✓] no_nulls_Timezone_ohe: Clean
# [✓] no_nulls_Sunrise_Sunset_ohe: Clean
# [✓] no_nulls_Civil_Twilight_ohe: Clean
# [✓] no_nulls_Nautical_Twilight_ohe: Clean
# [✓] no_nulls_Astronomical_Twilight_ohe: Clean
# [✓] no_nulls_City_idx: Clean
# [✓] no_nulls_County_idx: Clean
# [✓] no_nulls_State_idx: Clean
# [✓] no_nulls_Airport_Code_idx: Clean
# [✓] no_nulls_Wind_Direction_idx: Clean
# [✓] no_nulls_Start_Lat: Clean
# [✓] no_nulls_Start_Lng: Clean
# [x] no_nulls_End_Lat: 2722488 nulls found
# [x] no_nulls_End_Lng: 2722488 nulls found
# [✓] no_nulls_Distance(mi): Clean
# [x] no_nulls_Wind_Chill(F): 1599694 nulls found
# [x] no_nulls_Humidity(%): 139419 nulls found
# [x] no_nulls_Pressure(in): 112712 nulls found
# [x] no_nulls_Wind_Speed(mph): 457201 nulls found
# [x] no_nulls_Precipitation(in): 1762962 nulls found
# [✓] range_is_rush_hour: All in [0, 1]
# [✓] dropped_columns_removed: All columns meant to be dropped are dropped
#
# Overall: FAILED
#
# ============================================================
# SEMANTIC AGENT DECISIONS
# ============================================================
#
# Street             -> is_highway           (Regex: i-|hwy|highway|fwy|expressway|freeway)
# Rationale: Flags whether the street is an interstate or highway, targeting common terms for high-capacity roads.
#
# Street             -> is_local_street      (Regex: st|ave|blvd|rd|road|drive|dr)
# Rationale: Indicates local streets or avenues which are commonly used for navigation.
#
# Street             -> is_county_road       (Regex: cr-|county|state)
# Rationale: Captures roads designated as county or state routes, typical in less urban areas.
#
# Street             -> is_traffic_route     (Regex: us|route|highway|express)
# Rationale: Identifies major traffic routes that are not highways, important for traffic analysis.
#
# Street             -> is_unpaved_road      (Regex: dirt|unpaved|gravel|dust)
# Rationale: Captures unpaved road conditions which can be significant for accident severity.
#
# Street             -> is_commercial_area   (Regex: market|mall|shop|plaza|center)
# Rationale: Flags streets located in commercial zones which may affect accident outcomes due to higher foot traffic.
#
# Street             -> is_residential_area  (Regex: residential|neighborhood|subdivision|community|court)
# Rationale: Indicates residential street types which relate to lower speed limits and potentially different accident dynamics.
#
# Street             -> is_bridge            (Regex: bridge)
# Rationale: Flags instances of streets that are bridges, which are notable structures for accidents due to height and structure.
#
# Street             -> is_one_way_street    (Regex: one-way|one way)
# Rationale: Captures one-way streets important for understanding the directionality of accidents.
#
# Street             -> is_dead_end          (Regex: dead end|cul-de-sac)
# Rationale: Captures dead-end streets which can reflect specific traffic behaviors leading to accidents.
#
# Weather_Condition  -> is_rain              (Regex: rain|storm|drizzle|shower|thunder)
# Rationale: Identifies rainy weather conditions that significantly impact driving safety and accident likelihood.
#
# Weather_Condition  -> is_snow              (Regex: snow|sleet|ice|pellets|squall)
# Rationale: Flags snow and other icy conditions which impair vehicle control and increase accident severity.
#
# Weather_Condition  -> is_fog               (Regex: fog|haze|mist)
# Rationale: Captures reduced visibility conditions which are critical factors in accident occurrences.
#
# Weather_Condition  -> is_overcast          (Regex: overcast|cloudy|clouds)
# Rationale: Flags overcast conditions which may relate to driver behavior and visibility issues even if not extreme weather.
#
# Weather_Condition  -> is_fair              (Regex: fair|clear)
# Rationale: Identifies clear weather conditions which typically denote lower accident risks.
#
# Weather_Condition  -> is_windy             (Regex: windy|gale|breezy)
# Rationale: Captures windy conditions that can affect vehicle control, especially for lighter vehicles.
#
# Weather_Condition  -> is_hurricane         (Regex: hurricane|typhoon|cyclone)
# Rationale: Identifies severe weather conditions that are rarely but critically impactful on accident severity.
#
# Weather_Condition  -> is_freezing          (Regex: freezing|frozen|ice)
# Rationale: Flags freezing conditions which are crucial for understanding potential slip hazards and their impact on accidents.
#
# Weather_Condition  -> is_light_rain        (Regex: light rain|sprinkling|mist)
# Rationale: Captures lighter rain that might still affect driving but is less severe than heavy rain events.
#
# Weather_Condition  -> is_thunderstorm      (Regex: thunderstorm|lightning|storm)
# Rationale: Flags for the presence of thunderstorms which are critical for assessing severe weather impacts on driving conditions.
#
# Overall Rationale: The semantic expansions utilize comprehensive and strategic regex patterns that capture broad categories of street types and weather conditions. Each expansion is designed to enhance the predictive power of the model while ensuring broad coverage of recurring scenarios. The selections avoid rare events or overly specific indicators, focusing instead on those likely to influence accident severity frequently.
# ============================================================
#
#
# ============================================================
# NUMERIC AGENT DECISIONS
# ============================================================
#
# Time Features: ['is_rush_hour']
# Rationale: The rush hour periods (7-9 am and 5-7 pm) are peak times for traffic congestion, which can significantly impact accident severity. Extracting this feature helps to identify accidents that occurred during times of likely increased traffic.
#
# Binning: Visibility(mi) (custom_cuts)
# Rationale: Binning Visibility into categories of near-zero, poor, moderate, and clear helps to capture the effects of visibility on accident severity, as reduced visibility can dramatically increase the likelihood of an accident.
#
# Binning: Temperature(F) (custom_cuts)
# Rationale: Binning Temperature represents categories of freezing, cold, mild, and hot weather, which can affect road conditions and driver behavior, thus impacting accident severity.
#
# Interaction: Temperature(F) multiply Precipitation(in)
# Rationale: High temperature combined with precipitation can exacerbate slippery road conditions, leading to higher accident severity.
#
# Interaction: Wind_Speed(mph) multiply Precipitation(in)
# Rationale: Strong winds during precipitation can create hazardous driving conditions, contributing to a higher likelihood of accidents.
#
# Interaction: Distance(mi) ratio Duration_Minutes
# Rationale: The ratio of distance to duration provides an indication of traffic flow or speed, where lower ratios may indicate congestion, potentially increasing accident severity.
#
# Interaction: Humidity(%) multiply Wind_Speed(mph)
# Rationale: High humidity combined with strong winds can create uncomfortable driving conditions, which could distract drivers and contribute to accidents.
#
# Interaction: Temperature(F) multiply Wind_Speed(mph)
# Rationale: This interaction explores how temperature and wind speed together can affect road safety, particularly in cold conditions where wind can intensify the impact of low temperatures on driving.
#
# Scaling Applied: True (Strategy: standard)
# - Temperature(F): scale | Scaling Temperature ensures it's on a common scale with other continuous variables, which is crucial for models like logistic regression.
# - Humidity(%): scale | Humidity is a continuous variable that affects accident severity, so scaling it along with other features is necessary for model training.
# - Pressure(in): scale | Scaling Pressure allows for consistent input into models, especially since it's a continuous variable with potential impacts on driving conditions.
# - Visibility(mi): scale | Scaling Visibility helps normalize its effect on accident severity, making the model more sensitive to its variations.
# - Wind_Speed(mph): scale | Wind Speed should be scaled to enhance the model's ability to detect its influence on accident severity.
#
# Rationale: Applying standard scaling to these continuous features will ensure that the models can effectively process the data, improving convergence and the quality of the predictive model.
#
# Overall Rationale: The proposed numeric transformations are designed to enhance the model's ability to interpret key factors influencing accident severity, ensuring both robustness and validity in predictions.
# ============================================================
#
#
# ============================================================
# CATEGORICAL AGENT DECISIONS
# ============================================================
# Encode: ID                     -> drop
#  | Rationale: Column has 6183468 unique values, too granular and carries no predictive value.
# Encode: Source                 -> string_index_ohe
#  | Rationale: Column has 3 unique values, suitable for One Hot Encoding.
# Encode: Description            -> drop
#  | Rationale: Column has 3197356 unique values, too granular and carries no predictive value.
# Encode: City                   -> string_index_only
#  | Rationale: Column has 13425 unique values, high cardinality requires label encoding.
# Encode: County                 -> string_index_only
#  | Rationale: Column has 1855 unique values, high cardinality requires label encoding.
# Encode: State                  -> string_index_ohe
#  | Rationale: Column has 49 unique values, suitable for One Hot Encoding.
# Encode: Zipcode                -> drop
#  | Rationale: Column has 728289 unique values, too granular and carries no predictive value.
# Encode: Country                -> string_index_ohe
#  | Rationale: Column has 1 unique value, suitable for One Hot Encoding (but no effective categories).
# Encode: Timezone               -> string_index_ohe
#  | Rationale: Column has 5 unique values, suitable for One Hot Encoding.
# Encode: Airport_Code           -> string_index_only
#  | Rationale: Column has 2038 unique values, high cardinality requires label encoding.
# Encode: Wind_Direction         -> string_index_only
#  | Rationale: Column has 25 unique values, high cardinality requires label encoding.
# Encode: Sunrise_Sunset         -> string_index_ohe
#  | Rationale: Column has 3 unique values, suitable for One Hot Encoding.
# Encode: Civil_Twilight         -> string_index_ohe
#  | Rationale: Column has 3 unique values, suitable for One Hot Encoding.
# Encode: Nautical_Twilight      -> string_index_ohe
#  | Rationale: Column has 3 unique values, suitable for One Hot Encoding.
# Encode: Astronomical_Twilight  -> string_index_ohe
#  | Rationale: Column has 3 unique values, suitable for One Hot Encoding.
#
# Columns to Drop:
#  - Drop: Start_Time             | Rationale: Raw timestamp replaced by extracted features.
#  - Drop: ID                     | Rationale: Dropped because it has too many unique values.
#  - Drop: Description            | Rationale: Dropped because it has too many unique values.
#  - Drop: Zipcode                | Rationale: Dropped because it has too many unique values.
#  - Drop: Country                | Rationale: Dropped because it has only one unique value.
#
# Overall Rationale: The high cardinality columns like ID, Description, and Zipcode were dropped as they carry no predictive value. Other columns were encoded based on their cardinality suitability for MLlib compatibility.
# ============================================================
#
# Feature engineering compiled and executed. Assembled 62 features.
#
# === Feature Engineering Validation Report ===
# [✓] no_target_leakage: Severity excluded from assembler_cols
# [✓] no_nulls_is_rush_hour: Clean
# [✓] no_nulls_is_highway: Clean
# [✓] no_nulls_is_local_street: Clean
# [✓] no_nulls_is_county_road: Clean
# [✓] no_nulls_is_traffic_route: Clean
# [✓] no_nulls_is_unpaved_road: Clean
# [✓] no_nulls_is_commercial_area: Clean
# [✓] no_nulls_is_residential_area: Clean
# [✓] no_nulls_is_bridge: Clean
# [✓] no_nulls_is_one_way_street: Clean
# [✓] no_nulls_is_dead_end: Clean
# [✓] no_nulls_is_rain: Clean
# [✓] no_nulls_is_snow: Clean
# [✓] no_nulls_is_fog: Clean
# [✓] no_nulls_is_overcast: Clean
# [✓] no_nulls_is_fair: Clean
# [✓] no_nulls_is_windy: Clean
# [✓] no_nulls_is_hurricane: Clean
# [✓] no_nulls_is_freezing: Clean
# [✓] no_nulls_is_light_rain: Clean
# [✓] no_nulls_is_thunderstorm: Clean
# [x] no_nulls_Temperature(F)_multiply_Precipitation(in): 1784454 nulls found
# [x] no_nulls_Wind_Speed(mph)_multiply_Precipitation(in): 1827007 nulls found
# [x] no_nulls_Humidity(%)_multiply_Wind_Speed(mph): 482850 nulls found
# [x] no_nulls_Temperature(F)_multiply_Wind_Speed(mph): 475229 nulls found
# [✓] no_nulls_Amenity: Clean
# [✓] no_nulls_Bump: Clean
# [✓] no_nulls_Crossing: Clean
# [✓] no_nulls_Give_Way: Clean
# [✓] no_nulls_Junction: Clean
# [✓] no_nulls_No_Exit: Clean
# [✓] no_nulls_Railway: Clean
# [✓] no_nulls_Roundabout: Clean
# [✓] no_nulls_Station: Clean
# [✓] no_nulls_Stop: Clean
# [✓] no_nulls_Traffic_Calming: Clean
# [✓] no_nulls_Traffic_Signal: Clean
# [✓] no_nulls_Turning_Loop: Clean
# [x] no_nulls_Visibility(mi)_bin: 141807 nulls found
# [x] no_nulls_Temperature(F)_bin: 131243 nulls found
# [✓] no_nulls_Source_ohe: Clean
# [✓] no_nulls_City_idx: Clean
# [✓] no_nulls_County_idx: Clean
# [✓] no_nulls_State_ohe: Clean
# [✓] no_nulls_Country_ohe: Clean
# [✓] no_nulls_Timezone_ohe: Clean
# [✓] no_nulls_Airport_Code_idx: Clean
# [✓] no_nulls_Wind_Direction_idx: Clean
# [✓] no_nulls_Sunrise_Sunset_ohe: Clean
# [✓] no_nulls_Civil_Twilight_ohe: Clean
# [✓] no_nulls_Nautical_Twilight_ohe: Clean
# [✓] no_nulls_Astronomical_Twilight_ohe: Clean
# [✓] no_nulls_Start_Lat: Clean
# [✓] no_nulls_Start_Lng: Clean
# [x] no_nulls_End_Lat: 2722488 nulls found
# [x] no_nulls_End_Lng: 2722488 nulls found
# [✓] no_nulls_Distance(mi): Clean
# [x] no_nulls_Wind_Chill(F): 1599694 nulls found
# [x] no_nulls_Humidity(%): 139419 nulls found
# [x] no_nulls_Pressure(in): 112712 nulls found
# [x] no_nulls_Wind_Speed(mph): 457201 nulls found
# [x] no_nulls_Precipitation(in): 1762962 nulls found
# [✓] range_is_rush_hour: All in [0, 1]
# [✓] dropped_columns_removed: All columns meant to be dropped are dropped
#
# Overall: FAILED
#
# =======================================================
# PIPELINE RESULT
# =======================================================
# validation_status: approved
# validation_message: Accepted for feature engineering. quality_score=good, critical_issues=0, total_issues=0.
# auto_decision: {'decision': 'accept', 'quality_score': 'good', 'quality_value': 1.0, 'critical_issue_count': 0, 'total_issues': 0, 'reason': 'Accepted for feature engineering. quality_score=good, critical_issues=0, total_issues=0.'}
# feature_validation_status: None
# feature_validation_message: None
# feature_auto_decision: None
#
# Execution log:
#
#   Step 1: {'node': 'profile', 'quality_score': 'good', 'critical_issues': 0, 'total_issues': 0, 'test_schema_status': 'pass'}
#
#   Step 2: {'node': 'cleaning_gate', 'decision': 'accept', 'quality_score': 'good', 'quality_value': 1.0, 'critical_issue_count': 0, 'total_issues': 0, 'reason': 'Accepted for feature engineering. quality_score=good, critical_issues=0, total_issues=0.'}
#
# PIPELINE ENDED: feature engineering requires further refinement.

# %% [markdown]
# ## Inspect Agent State

# %%
# Only Validate cleaning Large dictionaries
"""
It correctly identifies "high" severity of missingness in multiple columns but
this does not appear to change the decision making?
"""
final_state['profile_train']
# final_state['profile_test']
# Out:
# {'profile': {'structural_overview': {'total_rows': 6183468,
#    'total_columns': 46,
#    'column_types': {'ID': 'categorical',
#     'Source': 'categorical',
#     'Severity': 'numerical',
#     'Start_Time': 'timestamp',
#     'End_Time': 'timestamp',
#     'Start_Lat': 'numerical',
#     'Start_Lng': 'numerical',
#     'End_Lat': 'numerical',
#     'End_Lng': 'numerical',
#     'Distance(mi)': 'numerical',
#     'Description': 'categorical',
#     'Street': 'categorical',
#     'City': 'categorical',
#     'County': 'categorical',
#     'State': 'categorical',
#     'Zipcode': 'categorical',
#     'Country': 'categorical',
#     'Timezone': 'categorical',
#     'Airport_Code': 'categorical',
#     'Weather_Timestamp': 'timestamp',
#     'Temperature(F)': 'numerical',
#     'Wind_Chill(F)': 'numerical',
#     'Humidity(%)': 'numerical',
#     'Pressure(in)': 'numerical',
#     'Visibility(mi)': 'numerical',
#     'Wind_Direction': 'categorical',
#     'Wind_Speed(mph)': 'numerical',
#     'Precipitation(in)': 'numerical',
#     'Weather_Condition': 'categorical',
#     'Amenity': 'boolean',
#     'Bump': 'boolean',
#     'Crossing': 'boolean',
#     'Give_Way': 'boolean',
#     'Junction': 'boolean',
#     'No_Exit': 'boolean',
#     'Railway': 'boolean',
#     'Roundabout': 'boolean',
#     'Station': 'boolean',
#     'Stop': 'boolean',
#     'Traffic_Calming': 'boolean',
#     'Traffic_Signal': 'boolean',
#     'Turning_Loop': 'boolean',
#     'Sunrise_Sunset': 'categorical',
#     'Civil_Twilight': 'categorical',
#     'Nautical_Twilight': 'categorical',
#     'Astronomical_Twilight': 'categorical'}},
#   'missing_values': {'ID': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Source': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Severity': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Start_Time': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'End_Time': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Start_Lat': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Start_Lng': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'End_Lat': {'null_count': 2722488,
#     'null_pct': 44.0285,
#     'severity': 'high',
#     'recommendation': 'check relevance'},
#    'End_Lng': {'null_count': 2722488,
#     'null_pct': 44.0285,
#     'severity': 'high',
#     'recommendation': 'check relevance'},
#    'Distance(mi)': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Description': {'null_count': 3,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Street': {'null_count': 8683,
#     'null_pct': 0.1404,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'City': {'null_count': 205,
#     'null_pct': 0.0033,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'County': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'State': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Zipcode': {'null_count': 1533,
#     'null_pct': 0.0248,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Country': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Timezone': {'null_count': 6266,
#     'null_pct': 0.1013,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Airport_Code': {'null_count': 18073,
#     'null_pct': 0.2923,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Weather_Timestamp': {'null_count': 96256,
#     'null_pct': 1.5567,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Temperature(F)': {'null_count': 131243,
#     'null_pct': 2.1225,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Wind_Chill(F)': {'null_count': 1599694,
#     'null_pct': 25.8705,
#     'severity': 'high',
#     'recommendation': 'check relevance'},
#    'Humidity(%)': {'null_count': 139419,
#     'null_pct': 2.2547,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Pressure(in)': {'null_count': 112712,
#     'null_pct': 1.8228,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Visibility(mi)': {'null_count': 141807,
#     'null_pct': 2.2933,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Wind_Direction': {'null_count': 140224,
#     'null_pct': 2.2677,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Wind_Speed(mph)': {'null_count': 457201,
#     'null_pct': 7.3939,
#     'severity': 'moderate',
#     'recommendation': 'impute'},
#    'Precipitation(in)': {'null_count': 1762962,
#     'null_pct': 28.5109,
#     'severity': 'high',
#     'recommendation': 'check relevance'},
#    'Weather_Condition': {'null_count': 138840,
#     'null_pct': 2.2453,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Amenity': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Bump': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Crossing': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Give_Way': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Junction': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'No_Exit': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Railway': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Roundabout': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Station': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Stop': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Traffic_Calming': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Traffic_Signal': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Turning_Loop': {'null_count': 0,
#     'null_pct': 0.0,
#     'severity': 'none',
#     'recommendation': 'keep'},
#    'Sunrise_Sunset': {'null_count': 18662,
#     'null_pct': 0.3018,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Civil_Twilight': {'null_count': 18662,
#     'null_pct': 0.3018,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Nautical_Twilight': {'null_count': 18662,
#     'null_pct': 0.3018,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'},
#    'Astronomical_Twilight': {'null_count': 18662,
#     'null_pct': 0.3018,
#     'severity': 'low',
#     'recommendation': 'impute/drop rows'}},
#   'numerical_analysis': {'Severity': {'mean': 2.2125,
#     'std': 0.4876,
#     'min': 1,
#     'max': 4,
#     'skewness': 1.8145,
#     'kurtosis': 3.2918,
#     'outlier_count': 0,
#     'distribution': 'high_skew',
#     'imputation_recommendation': 'not needed'},
#    'Start_Lat': {'mean': 36.2019,
#     'std': 5.0761,
#     'min': 24.5548,
#     'max': 49.0022,
#     'skewness': -0.0724,
#     'kurtosis': -0.5318,
#     'outlier_count': 0,
#     'distribution': 'normal',
#     'imputation_recommendation': 'not needed'},
#    'Start_Lng': {'mean': -94.7004,
#     'std': 17.3914,
#     'min': -124.6238,
#     'max': -67.4036,
#     'skewness': -0.4833,
#     'kurtosis': -1.3628,
#     'outlier_count': 0,
#     'distribution': 'normal',
#     'imputation_recommendation': 'not needed'},
#    'End_Lat': {'mean': 36.2627,
#     'std': 5.2729,
#     'min': 24.57,
#     'max': 49.075,
#     'skewness': -0.1585,
#     'kurtosis': -0.5564,
#     'outlier_count': 0,
#     'distribution': 'normal',
#     'imputation_recommendation': 'mean'},
#    'End_Lng': {'mean': -95.7212,
#     'std': 18.1077,
#     'min': -124.5457,
#     'max': -67.4035,
#     'skewness': -0.3659,
#     'kurtosis': -1.5554,
#     'outlier_count': 0,
#     'distribution': 'normal',
#     'imputation_recommendation': 'mean'},
#    'Distance(mi)': {'mean': 0.5622,
#     'std': 1.785,
#     'min': 0,
#     'max': 441.75,
#     'skewness': 21.1923,
#     'kurtosis': 1817.7446,
#     'outlier_count': 771028,
#     'distribution': 'high_skew',
#     'imputation_recommendation': 'not needed'},
#    'Temperature(F)': {'mean': 61.6664,
#     'std': 19.0117,
#     'min': -89.0,
#     'max': 207.0,
#     'skewness': -0.5136,
#     'kurtosis': -0.0013,
#     'outlier_count': 40280,
#     'distribution': 'moderate_skew',
#     'imputation_recommendation': 'median'},
#    'Wind_Chill(F)': {'mean': 58.2561,
#     'std': 22.3867,
#     'min': -89.0,
#     'max': 207.0,
#     'skewness': -0.6722,
#     'kurtosis': 0.1524,
#     'outlier_count': 35000,
#     'distribution': 'moderate_skew',
#     'imputation_recommendation': 'median'},
#    'Humidity(%)': {'mean': 64.831,
#     'std': 22.8229,
#     'min': 1.0,
#     'max': 100.0,
#     'skewness': -0.3949,
#     'kurtosis': -0.7237,
#     'outlier_count': 0,
#     'distribution': 'normal',
#     'imputation_recommendation': 'mean'},
#    'Pressure(in)': {'mean': 29.5389,
#     'std': 1.0069,
#     'min': 0,
#     'max': 58.63,
#     'skewness': -3.6354,
#     'kurtosis': 22.2644,
#     'outlier_count': 354585,
#     'distribution': 'high_skew',
#     'imputation_recommendation': 'median'},
#    'Visibility(mi)': {'mean': 9.0901,
#     'std': 2.6903,
#     'min': 0,
#     'max': 140.0,
#     'skewness': 2.3178,
#     'kurtosis': 81.2874,
#     'outlier_count': 0,
#     'distribution': 'high_skew',
#     'imputation_recommendation': 'median'},
#    'Wind_Speed(mph)': {'mean': 7.6854,
#     'std': 5.4132,
#     'min': 0,
#     'max': 1087.0,
#     'skewness': 7.2692,
#     'kurtosis': 953.5378,
#     'outlier_count': 168459,
#     'distribution': 'high_skew',
#     'imputation_recommendation': 'median'},
#    'Precipitation(in)': {'mean': 0.0084,
#     'std': 0.1097,
#     'min': 0,
#     'max': 36.47,
#     'skewness': 87.735,
#     'kurtosis': 11424.7676,
#     'outlier_count': 0,
#     'distribution': 'high_skew',
#     'imputation_recommendation': 'median'}},
#   'categorical_analysis': {'ID': {'distinct_count': 6183468,
#     'top_5_values': {'A-5199340': 1,
#      'A-5199403': 1,
#      'A-5199316': 1,
#      'A-5199519': 1,
#      'A-5199345': 1},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'group_rare_categories_and_label_encode'},
#    'Source': {'distinct_count': 3,
#     'top_5_values': {'Source1': 3460980, 'Source2': 2644320, 'Source3': 78168},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'one_hot_encode'},
#    'Description': {'distinct_count': 3197356,
#     'top_5_values': {'A crash has occurred causing no to minimum delays. Use caution.': 7688,
#      'Accident': 5274,
#      'An unconfirmed report of a crash has been received. Use caution.': 3048,
#      'A crash has occurred use caution.': 2327,
#      'A crash has occurred with minimal delay to traffic. Prepare to slow or move over for worker safety.': 2141},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'group_rare_categories_and_label_encode'},
#    'Street': {'distinct_count': 307939,
#     'top_5_values': {'I-95 N': 62668,
#      'I-95 S': 59621,
#      'I-5 N': 57599,
#      'I-10 E': 44438,
#      'I-10 W': 43100},
#     'near_zero_variance': False,
#     'extraction_hint': {'type': 'string_keyword_extraction',
#      'discovered_patterns': ['i',
#       'rd',
#       'st',
#       'ave',
#       'blvd',
#       'fwy',
#       'dr',
#       'highway',
#       'us',
#       'hwy'],
#      'coverage_pct': 1.01},
#     'encoding_recommendation': 'extract_binary_features'},
#    'City': {'distinct_count': 13425,
#     'top_5_values': {'Miami': 149411,
#      'Houston': 135760,
#      'Los Angeles': 125067,
#      'Charlotte': 110672,
#      'Dallas': 104803},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'group_rare_categories_and_label_encode'},
#    'County': {'distinct_count': 1855,
#     'top_5_values': {'Los Angeles': 420810,
#      'Miami-Dade': 201336,
#      'Orange': 193255,
#      'Harris': 145031,
#      'Dallas': 125720},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'group_rare_categories_and_label_encode'},
#    'State': {'distinct_count': 49,
#     'top_5_values': {'CA': 1392959,
#      'FL': 704133,
#      'TX': 466068,
#      'SC': 306408,
#      'NY': 278583},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'group_rare_categories_and_label_encode'},
#    'Zipcode': {'distinct_count': 728289,
#     'top_5_values': {'91761': 9045,
#      '91706': 8058,
#      '92407': 7141,
#      '92507': 7116,
#      '33186': 6665},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'group_rare_categories_and_label_encode'},
#    'Country': {'distinct_count': 1,
#     'top_5_values': {'US': 6183468},
#     'near_zero_variance': True,
#     'extraction_hint': None,
#     'encoding_recommendation': 'one_hot_encode'},
#    'Timezone': {'distinct_count': 5,
#     'top_5_values': {'US/Eastern': 2864878,
#      'US/Pacific': 1650256,
#      'US/Central': 1316586,
#      'US/Mountain': 345482,
#      'None': 6266},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'one_hot_encode'},
#    'Airport_Code': {'distinct_count': 2038,
#     'top_5_values': {'KCQT': 94548,
#      'KRDU': 86075,
#      'KMCJ': 81385,
#      'KBNA': 79354,
#      'KCLT': 77690},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'group_rare_categories_and_label_encode'},
#    'Wind_Direction': {'distinct_count': 25,
#     'top_5_values': {'CALM': 769616,
#      'S': 335865,
#      'SSW': 307660,
#      'W': 307034,
#      'WNW': 303388},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'group_rare_categories_and_label_encode'},
#    'Weather_Condition': {'distinct_count': 142,
#     'top_5_values': {'Fair': 2048103,
#      'Mostly Cloudy': 813458,
#      'Cloudy': 653510,
#      'Clear': 647393,
#      'Partly Cloudy': 559315},
#     'near_zero_variance': False,
#     'extraction_hint': {'type': 'string_keyword_extraction',
#      'discovered_patterns': ['fair',
#       'cloudy',
#       'clear',
#       'light',
#       'rain',
#       'overcast',
#       'scattered',
#       'clouds',
#       'snow',
#       'fog'],
#      'coverage_pct': 33.12},
#     'encoding_recommendation': 'extract_binary_features'},
#    'Sunrise_Sunset': {'distinct_count': 3,
#     'top_5_values': {'Day': 4268114, 'Night': 1896692, 'None': 18662},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'one_hot_encode'},
#    'Civil_Twilight': {'distinct_count': 3,
#     'top_5_values': {'Day': 4557433, 'Night': 1607373, 'None': 18662},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'one_hot_encode'},
#    'Nautical_Twilight': {'distinct_count': 3,
#     'top_5_values': {'Day': 4861795, 'Night': 1303011, 'None': 18662},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'one_hot_encode'},
#    'Astronomical_Twilight': {'distinct_count': 3,
#     'top_5_values': {'Day': 5102786, 'Night': 1062020, 'None': 18662},
#     'near_zero_variance': False,
#     'extraction_hint': None,
#     'encoding_recommendation': 'one_hot_encode'}},
#   'timestamp_analysis': {'Start_Time': {'min': '2016-01-14 20:18:33',
#     'max': '2023-03-31 23:30:00',
#     'yearly_distribution': {'2020': 943515,
#      '2021': 1251047,
#      '2022': 1410092,
#      '2018': 714827,
#      '2023': 197101,
#      '2016': 328661,
#      '2019': 763381,
#      '2017': 574844},
#     'sparse_years': [],
#     'temporal_consistency': 'consistent'}},
#   'target_analysis': {'column': 'Severity',
#    'class_distribution': {'4': 163786, '2': 4925732, '3': 1040205, '1': 53745},
#    'imbalance_ratio': 91.65,
#    'imbalance_classification': 'severe_imbalance',
#    'smote_recommendation': 'strongly recommend SMOTE'},
#   'correlation_analysis': {'highly_correlated_pairs': [{'col1': 'End_Lat',
#      'col2': 'End_Lng',
#      'correlation': -0.9465,
#      'recommendation': 'feature reduction'}],
#    'near_duplicate_pairs': []},
#   'quality_summary': {'total_issues': 0,
#    'critical_issues': [],
#    'warnings': [],
#    'overall_quality_score': 'good'}},
#  'cleaning_rec': [{'action': 'impute', 'column': 'Street', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'City', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Zipcode', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Timezone', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Airport_Code', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Weather_Timestamp', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Temperature(F)', 'strategy': 'median'},
#   {'action': 'impute', 'column': 'Humidity(%)', 'strategy': 'mean'},
#   {'action': 'impute', 'column': 'Pressure(in)', 'strategy': 'median'},
#   {'action': 'impute', 'column': 'Visibility(mi)', 'strategy': 'median'},
#   {'action': 'impute', 'column': 'Wind_Direction', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Wind_Speed(mph)', 'strategy': 'median'},
#   {'action': 'impute', 'column': 'Weather_Condition', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Sunrise_Sunset', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Civil_Twilight', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Nautical_Twilight', 'strategy': 'mode'},
#   {'action': 'impute', 'column': 'Astronomical_Twilight', 'strategy': 'mode'}],
#  'feature_eng_rec': [{'action': 'encode',
#    'column': 'ID',
#    'method': 'group_rare_categories_and_label_encode',
#    'reason': 'Column has 6183468 unique values'},
#   {'action': 'encode',
#    'column': 'Source',
#    'method': 'one_hot_encode',
#    'reason': 'Column has 3 unique values'},
#   {'action': 'encode',
#    'column': 'Description',
#    'method': 'group_rare_categories_and_label_encode',
#    'reason': 'Column has 3197356 unique values'},
#   {'action': 'extract_binary_features',
#    'column': 'Street',
#    'logic': 'string_keyword_extraction',
#    'keywords': ['i',
#     'rd',
#     'st',
#     'ave',
#     'blvd',
#     'fwy',
#     'dr',
#     'highway',
#     'us',
#     'hwy'],
#    'reason': 'High cardinality with repeating semantic tokens'},
#   {'action': 'encode',
#    'column': 'City',
#    'method': 'group_rare_categories_and_label_encode',
#    'reason': 'Column has 13425 unique values'},
#   {'action': 'encode',
#    'column': 'County',
#    'method': 'group_rare_categories_and_label_encode',
#    'reason': 'Column has 1855 unique values'},
#   {'action': 'encode',
#    'column': 'State',
#    'method': 'group_rare_categories_and_label_encode',
#    'reason': 'Column has 49 unique values'},
#   {'action': 'encode',
#    'column': 'Zipcode',
#    'method': 'group_rare_categories_and_label_encode',
#    'reason': 'Column has 728289 unique values'},
#   {'action': 'encode',
#    'column': 'Country',
#    'method': 'one_hot_encode',
#    'reason': 'Column has 1 unique values'},
#   {'action': 'encode',
#    'column': 'Timezone',
#    'method': 'one_hot_encode',
#    'reason': 'Column has 5 unique values'},
#   {'action': 'encode',
#    'column': 'Airport_Code',
#    'method': 'group_rare_categories_and_label_encode',
#    'reason': 'Column has 2038 unique values'},
#   {'action': 'encode',
#    'column': 'Wind_Direction',
#    'method': 'group_rare_categories_and_label_encode',
#    'reason': 'Column has 25 unique values'},
#   {'action': 'extract_binary_features',
#    'column': 'Weather_Condition',
#    'logic': 'string_keyword_extraction',
#    'keywords': ['fair',
#     'cloudy',
#     'clear',
#     'light',
#     'rain',
#     'overcast',
#     'scattered',
#     'clouds',
#     'snow',
#     'fog'],
#    'reason': 'High cardinality with repeating semantic tokens'},
#   {'action': 'encode',
#    'column': 'Sunrise_Sunset',
#    'method': 'one_hot_encode',
#    'reason': 'Column has 3 unique values'},
#   {'action': 'encode',
#    'column': 'Civil_Twilight',
#    'method': 'one_hot_encode',
#    'reason': 'Column has 3 unique values'},
#   {'action': 'encode',
#    'column': 'Nautical_Twilight',
#    'method': 'one_hot_encode',
#    'reason': 'Column has 3 unique values'},
#   {'action': 'encode',
#    'column': 'Astronomical_Twilight',
#    'method': 'one_hot_encode',
#    'reason': 'Column has 3 unique values'},
#   {'action': 'balance_target', 'method': 'SMOTE', 'ratio': 91.65}],
#  'quality_score': 'good'}

# %%
# Whole agent state
# final_state

# Validate cleaning's conclusion
final_state["validation_status"]
final_state["validation_message"]
final_state["auto_decision"]
# Out:
# {'decision': 'accept',
#  'quality_score': 'good',
#  'quality_value': 1.0,
#  'critical_issue_count': 0,
#  'total_issues': 0,
#  'reason': 'Accepted for feature engineering. quality_score=good, critical_issues=0, total_issues=0.'}

# %% [markdown]
# ## Stop Spark

# %%
spark.stop()
